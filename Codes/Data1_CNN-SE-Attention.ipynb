# %% [markdown]
# ### Libraries and data loading

# %%
# import libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import datetime
import itertools
import h5py
import matplotlib.dates as mdates

# %matplotlib inline
# Out:
# 2024-12-18 19:12:15.658465: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 19:12:15.785854: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 19:12:15.817377: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 19:12:16.399938: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-12-18 19:12:16.400011: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-12-18 19:12:16.400016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# check tensorflow version
print("tensorflow version:", tf.__version__)
# check available gpu
gpus =  tf.config.list_physical_devices('GPU')
print("available gpus:", gpus)
# limit the gpu usage, prevent it from allocating all gpu memory for a simple model
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# check number of cpus available
print("available cpus:", os.cpu_count())
# Out:
# tensorflow version: 2.10.0
# available gpus: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# available cpus: 112
# 2024-12-18 19:12:18.798026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:18.808980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:18.809263: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
import tensorflow as tf
sys_details = tf.sysconfig.get_build_info()
sys_details["cuda_version"]
# Out:
# '11.2'

# %%
# define the data location and load data

data_folder = os.path.join("data")
data_path = os.path.join(data_folder, "2017_2019_images_pv_processed.hdf5")

# !change model name for different models!
model_name = 'SUNSET_nowcast_CNN_SE_Attention_2017_2019_data'
output_folder = os.path.join("model_output", model_name)
if os.path.isdir(output_folder)==False:
    os.makedirs(output_folder)

print("data_folder:", data_folder)
print("data_path:", data_path)
print("output_folder:", output_folder)
# Out:
# data_folder: data
# data_path: data/2017_2019_images_pv_processed.hdf5
# output_folder: model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data

# %%
# generate handler for the hdf5 data
forecast_dataset = h5py.File(data_path, 'r')

# show structure of the hdf5 data
def get_all(name):
    if name!=None:
        print(forecast_dataset[name])
    
forecast_dataset.visit(get_all)
# Out:
# <HDF5 group "/test" (2 members)>
# <HDF5 dataset "images_log": shape (14003, 64, 64, 3), type "|u1">
# <HDF5 dataset "pv_log": shape (14003,), type "<f8">
# <HDF5 group "/trainval" (2 members)>
# <HDF5 dataset "images_log": shape (349372, 64, 64, 3), type "|u1">
# <HDF5 dataset "pv_log": shape (349372,), type "<f8">

# %%
print('-'*50)
# get the input dimension for constructing the model
img_side_len = forecast_dataset['trainval']['images_log'].shape[1]

num_log_term = forecast_dataset['trainval']['images_log'].shape[1]

num_color_channel = forecast_dataset['trainval']['images_log'].shape[3]
image_input_dim = [img_side_len,img_side_len,num_color_channel]

print("image side length:", img_side_len)

print("number of log terms:", num_log_term)

print("number of color channels:", num_color_channel)
print("input image dimension:", image_input_dim)

# load time stamps into the memory
times_trainval = np.load(os.path.join(data_folder,"times_trainval.npy"),allow_pickle=True)
print("times_trainval.shape:", times_trainval.shape)

# read through the dataset once in order to cache it but not store it into the memory
## read the data by batch
num_samples = len(times_trainval)
batch_size = num_samples//5
indices = np.arange(num_samples)
print('-'*50)
print('data reading start...')
for i in range(int(num_samples / batch_size) + 1):
    start_time = time.time()
    start_idx = (i * batch_size) % num_samples
    idxs = indices[start_idx:start_idx + batch_size]
    _ = forecast_dataset['trainval']['images_log'][idxs]
    _ = forecast_dataset['trainval']['pv_log'][idxs]
    end_time = time.time()
    print("batch {0} samples: {1} to {2}, {3:.2f}% finished, processing time {4:.2f}s"
          .format(i+1, idxs[0],idxs[-1],(idxs[-1]/num_samples)*100,(end_time-start_time)))

# temporially close the dataset, will use "with" statement to open it when we use it
forecast_dataset.close()
# Out:
# --------------------------------------------------
# image side length: 64
# number of log terms: 64
# number of color channels: 3
# input image dimension: [64, 64, 3]
# times_trainval.shape: (349372,)
# --------------------------------------------------
# data reading start...
# batch 1 samples: 0 to 69873, 20.00% finished, processing time 0.60s
# batch 2 samples: 69874 to 139747, 40.00% finished, processing time 0.60s
# batch 3 samples: 139748 to 209621, 60.00% finished, processing time 0.60s
# batch 4 samples: 209622 to 279495, 80.00% finished, processing time 0.60s
# batch 5 samples: 279496 to 349369, 100.00% finished, processing time 0.61s
# batch 6 samples: 349370 to 349371, 100.00% finished, processing time 0.00s

# %% [markdown]
# ### Input data pipeline helper functions

# %%
# day block shuffling of the time stamps, and return shuffled indices
def day_block_shuffle(times_trainval):
    
    # Only keep the date of each time point
    dates_trainval = np.zeros_like(times_trainval, dtype=datetime.date)
    for i in range(len(times_trainval)):
        dates_trainval[i] = times_trainval[i].date()

    # Chop the indices into blocks, so that each block contains the indices of the same day
    unique_dates = np.unique(dates_trainval)
    blocks = []
    for i in range(len(unique_dates)):
        blocks.append(np.where(dates_trainval == unique_dates[i])[0])

    # shuffle the blocks, and chain it back together
    np.random.seed(1)
    np.random.shuffle(blocks)
    shuffled_indices = np.asarray(list(itertools.chain.from_iterable(blocks)))

    return shuffled_indices

# %%
# a cross validation generator function for spliting the dayblock shuffled indices into training and validation
def cv_split(split_data, fold_index, num_fold):
    '''
    input:
    split_data: the dayblock shuffled indices to be splitted
    fold_index: the ith fold chosen as the validation, used for generating the seed for random shuffling
    num_fold: N-fold cross validation
    output:
    data_train: the train data indices
    data_val: the validation data indices
    '''
    # randomly divides into a training set and a validation set
    num_samples = len(split_data)
    indices = np.arange(num_samples)

    # finding training and validation indices
    val_mask = np.zeros(len(indices), dtype=bool)
    val_mask[int(fold_index / num_fold * num_samples):int((fold_index + 1) / num_fold * num_samples)] = True
    val_indices = indices[val_mask]
    train_indices = indices[np.logical_not(val_mask)]

    # shuffle indices
    np.random.seed(fold_index)
    np.random.shuffle(train_indices)
    np.random.shuffle(val_indices)
    
    data_train = split_data[train_indices]
    data_val = split_data[val_indices]

    return data_train,data_val

# %%
# a mapping function from the indices to the corresponding features and labels 
def data_loader(hdf5_data_path,sample_idx,batch_size=256):
    '''
    input:
    hdf5_data_path: path to hdf5 data file
    sample_idx: 
        for training and validation:
            dayblock shuffled indices with cross-validation split into training and validation
            either training or validation indices will be input
        for testing: the indices are not shuffled
    is_trainval: a flag, True for trainig and validation
    output:
    dataset: dataset for training, validation
    '''

    def mapping_func_py(hdf5_data_path,sample_idx):
        '''
        mapping indices to corresponding images and pviance data in hdf5 (python expression)
        '''
        # convert EagerTensor to str or numpy array
        hdf5_data_path = hdf5_data_path.numpy().decode() 
        # sort the sample indices as hdf5 requires increasing order index for data retrieval
        sample_idx = sorted(sample_idx.numpy())

        with h5py.File(hdf5_data_path,'r') as f:

            # read in the data
            images_log = f['trainval']['images_log'][sample_idx]
            pv_log = f['trainval']['pv_log'][sample_idx]

            # normalize image data to [0,1]
            images_log = tf.image.convert_image_dtype(images_log, tf.float32)
            
            # convert pv data to tf.tensor
            pv_log = tf.convert_to_tensor(pv_log, dtype=tf.float32)
            
            return images_log, pv_log

    def mapping_func_tf(hdf5_data_path,sample_idx):
        '''
        a wrapper mapping function to get the nested data structure 
        the output type of tf.py_function cannot be a nested sequence when using a tf.py_function with the tf.data API
        '''
        images_log, pv_log = tf.py_function(func=mapping_func_py,
                                                           inp=[hdf5_data_path, sample_idx], 
                                                           Tout=(tf.float32, tf.float32))
        return images_log, pv_log
    
    
    # create the indices dataset
    idx_ds = tf.data.Dataset.from_tensor_slices(sample_idx)
    # shuffle and batch the indices
    idx_ds = idx_ds.shuffle(buffer_size = idx_ds.cardinality().numpy(),seed=0)
    idx_ds = idx_ds.batch(batch_size).repeat().prefetch(tf.data.experimental.AUTOTUNE)
    
    # indices dataset mapping to images and pviance data
    # returning dataset with the following nested structure: (images_log, pv_log), pv_pred
    dataset = idx_ds.map(lambda x: mapping_func_tf(hdf5_data_path,x),
                         num_parallel_calls=tf.data.experimental.AUTOTUNE)
    
    return dataset

# %% [markdown]
# ### Model architecture

# %%
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dropout, Dense, Reshape, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Model characteristics
num_filters = 24
kernel_size = [3, 3]
pool_size = [2, 2]
strides = 2
dense_size = 1024
drop_rate = 0.4

# define training time parameters
num_epochs = 200 #(The maximum epoches set to 200 and there might be early stopping depends on validation loss)
num_fold = 10 # 10-fold cross-validation
batch_size = 256
learning_rate = 3e-06

def se_attention(input_feature, reduction_ratio=8):

    channel = input_feature.shape[-1]
    
    # Squeeze: Global Average Pooling
    squeeze = GlobalAveragePooling2D()(input_feature)
    
    # Excitation: Fully Connected layers
    excitation = Dense(channel // reduction_ratio, activation='relu')(squeeze)
    excitation = Dense(channel, activation='sigmoid')(excitation)
    excitation = Reshape((1, 1, channel))(excitation)
    
    # Scale the input feature map
    return Multiply()([input_feature, excitation])


# Model architecture with SE Attention
def sunset_model():
    ## Input
    x_in = keras.Input(shape=(64, 64, 3))  # Update shape to match input data (RGB)

    ## 1st convolution block with SE Attention
    x = Conv2D(12, kernel_size, padding="same", activation='relu')(x_in)
    x = BatchNormalization()(x)
    x = se_attention(x)  # Replace with SE Attention
    x = MaxPooling2D(pool_size, strides)(x)

    ## 2nd convolution block with SE Attention
    x = Conv2D(24, kernel_size, padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = se_attention(x)  # Replace with SE Attention
    x = MaxPooling2D(pool_size, strides)(x)

    # Flatten the convolution output for connection with Dense layers
    x = Flatten()(x)

    # Fully connected layers
    x = Dense(dense_size, activation='relu')(x)
    x = Dropout(drop_rate)(x)
    x = Dense(dense_size, activation='relu')(x)
    x = Dropout(drop_rate)(x)

    ## Regression to prediction target
    y_out = keras.layers.Dense(units=1)(x)

    # Construct the model
    model = keras.Model(inputs=x_in, outputs=y_out)

    # Compile the model with an optimizer
    optimizer = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

    return model

# Example input dimensions (update based on your dataset)
image_input_dim = (64, 64, 24)  # Example: 64x64 images with 24 channels (time-series images)

# Build the model
model = sunset_model()

# Display the model architecture
model.summary()
# Out:
# 2024-12-18 19:12:25.029794: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 19:12:25.037240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:25.037567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:25.037794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:25.596878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:25.597226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:25.597515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 19:12:25.597762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12897 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 12)   336         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 12)  48          ['conv2d[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 12)          0           ['batch_normalization[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1)            13          ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 12)           24          ['dense[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 12)     0           ['dense_1[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 12)   0           ['batch_normalization[0][0]',
#                                                                   'reshape[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 12)   0           ['multiply[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 24)   2616        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 24)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  global_average_pooling2d_1 (Gl  (None, 24)          0           ['batch_normalization_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 3)            75          ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 24)           96          ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 24)     0           ['dense_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 32, 24)   0           ['batch_normalization_1[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 24)  0           ['multiply_1[0][0]']
#
#  flatten (Flatten)              (None, 6144)         0           ['max_pooling2d_1[0][0]']
#
#  dense_4 (Dense)                (None, 1024)         6292480     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1024)         1049600     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 1)            1025        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7,346,409
# Trainable params: 7,346,337
# Non-trainable params: 72
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model training and validation

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import os
import numpy as np
import matplotlib.pyplot as plt

# generate dayblock shuffled indices
indices_dayblock_shuffled = day_block_shuffle(times_trainval)

# initialize loss history list
train_loss_hist = []
val_loss_hist = []



for i in range(num_fold):

    # construct and compile model for each repetition to reinitialize the model weights
    keras.backend.clear_session()
    model = sunset_model()
    model.compile(optimizer=keras.optimizers.Adam(learning_rate), loss='mse')

    # implementing 10-fold cross-validation
    print('Repetition {0} model training started ...'.format(i+1))

    # creating folder for saving model checkpoint
    save_directory = os.path.join(output_folder, 'repetition_' + str(i+1))
    if not os.path.exists(save_directory):
        os.makedirs(save_directory)

    # training and validation data preparation
    ## generate indices dataset for training and validation
    indices_train, indices_val = cv_split(indices_dayblock_shuffled, i, num_fold)
    ## load data from dataloader
    ds_train_batched = data_loader(data_path, indices_train)
    ds_val_batched = data_loader(data_path, indices_val, batch_size=500)

     # define callbacks for training
    ## early stopping rule: if the validation loss stop decreasing for 5 consecutive epoches
    earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    ## model check point: save model checkpoint for later use
    checkpoint = keras.callbacks.ModelCheckpoint(os.path.join(save_directory,'best_model_repitition_'+str(i+1)+'.h5'), 
                                monitor='val_loss', mode='min', save_best_only=True, verbose=1)

    # training the model and record training and validation loss
    history = model.fit(ds_train_batched, epochs=num_epochs, steps_per_epoch=len(indices_train)//batch_size+1,
                               verbose=1, callbacks=[earlystop,checkpoint], validation_data=ds_val_batched,
                              validation_steps=len(indices_val)//batch_size+1)
    train_loss_hist.append(history.history['loss'])
    val_loss_hist.append(history.history['val_loss'])
    

# Saving model training and validation loss history after all repetitions
np.save(os.path.join(output_folder, 'train_loss_hist.npy'), np.array(train_loss_hist))
np.save(os.path.join(output_folder, 'val_loss_hist.npy'), np.array(val_loss_hist))

# Plot training and validation history for all repetitions
for i in range(num_fold):
    plt.plot(train_loss_hist[i], label=f'train Repetition {i+1}')
    plt.plot(val_loss_hist[i], label=f'validation Repetition {i+1}')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Repetitions')
plt.show()
# Out:
# Repetition 1 model training started ...
# Epoch 1/200
# 2024-12-18 19:12:34.338955: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-12-18 19:12:35.835188: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1229/1229 [==============================] - ETA: 0s - loss: 30.8807
# Epoch 1: val_loss improved from inf to 9.76112, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 46s 35ms/step - loss: 30.8807 - val_loss: 9.7611
# Epoch 2/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 8.2034
# Epoch 2: val_loss improved from 9.76112 to 7.63590, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 8.1999 - val_loss: 7.6359
# Epoch 3/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 6.6013
# Epoch 3: val_loss improved from 7.63590 to 6.59848, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.5997 - val_loss: 6.5985
# Epoch 4/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.7634
# Epoch 4: val_loss improved from 6.59848 to 6.06735, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.7634 - val_loss: 6.0674
# Epoch 5/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.2163
# Epoch 5: val_loss improved from 6.06735 to 5.85564, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.2164 - val_loss: 5.8556
# Epoch 6/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.8361
# Epoch 6: val_loss improved from 5.85564 to 5.49458, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.8361 - val_loss: 5.4946
# Epoch 7/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.5325
# Epoch 7: val_loss improved from 5.49458 to 5.36444, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.5320 - val_loss: 5.3644
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.2945
# Epoch 8: val_loss improved from 5.36444 to 5.25012, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.2946 - val_loss: 5.2501
# Epoch 9/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.0846
# Epoch 9: val_loss improved from 5.25012 to 5.03978, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.0849 - val_loss: 5.0398
# Epoch 10/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.9451
# Epoch 10: val_loss improved from 5.03978 to 4.99640, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.9451 - val_loss: 4.9964
# Epoch 11/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.7897
# Epoch 11: val_loss improved from 4.99640 to 4.95980, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.7893 - val_loss: 4.9598
# Epoch 12/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.6827
# Epoch 12: val_loss improved from 4.95980 to 4.83451, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6827 - val_loss: 4.8345
# Epoch 13/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.5822
# Epoch 13: val_loss did not improve from 4.83451
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5820 - val_loss: 4.9342
# Epoch 14/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4734
# Epoch 14: val_loss did not improve from 4.83451
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4734 - val_loss: 4.8965
# Epoch 15/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.3835
# Epoch 15: val_loss improved from 4.83451 to 4.76757, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3823 - val_loss: 4.7676
# Epoch 16/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.3186
# Epoch 16: val_loss improved from 4.76757 to 4.70877, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3182 - val_loss: 4.7088
# Epoch 17/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2241
# Epoch 17: val_loss improved from 4.70877 to 4.70071, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.2232 - val_loss: 4.7007
# Epoch 18/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.1697
# Epoch 18: val_loss improved from 4.70071 to 4.64231, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1697 - val_loss: 4.6423
# Epoch 19/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1090
# Epoch 19: val_loss did not improve from 4.64231
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1090 - val_loss: 4.7202
# Epoch 20/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.0646
# Epoch 20: val_loss did not improve from 4.64231
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0647 - val_loss: 4.6767
# Epoch 21/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9974
# Epoch 21: val_loss improved from 4.64231 to 4.63170, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9974 - val_loss: 4.6317
# Epoch 22/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.9645
# Epoch 22: val_loss did not improve from 4.63170
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9654 - val_loss: 4.8258
# Epoch 23/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.9194
# Epoch 23: val_loss did not improve from 4.63170
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9191 - val_loss: 4.7330
# Epoch 24/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.8666
# Epoch 24: val_loss did not improve from 4.63170
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8667 - val_loss: 4.7808
# Epoch 25/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8252
# Epoch 25: val_loss improved from 4.63170 to 4.59285, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8253 - val_loss: 4.5928
# Epoch 26/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.7866
# Epoch 26: val_loss improved from 4.59285 to 4.49766, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7875 - val_loss: 4.4977
# Epoch 27/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.7349
# Epoch 27: val_loss improved from 4.49766 to 4.46295, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7349 - val_loss: 4.4630
# Epoch 28/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.7101
# Epoch 28: val_loss did not improve from 4.46295
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7101 - val_loss: 4.6372
# Epoch 29/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.6749
# Epoch 29: val_loss did not improve from 4.46295
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.6749 - val_loss: 4.6408
# Epoch 30/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.6398
# Epoch 30: val_loss did not improve from 4.46295
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.6399 - val_loss: 4.5936
# Epoch 31/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.6084
# Epoch 31: val_loss improved from 4.46295 to 4.45775, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.6084 - val_loss: 4.4577
# Epoch 32/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.5795
# Epoch 32: val_loss did not improve from 4.45775
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.5797 - val_loss: 4.5537
# Epoch 33/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.5246
# Epoch 33: val_loss did not improve from 4.45775
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.5242 - val_loss: 4.5265
# Epoch 34/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.5112
# Epoch 34: val_loss did not improve from 4.45775
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.5115 - val_loss: 4.7680
# Epoch 35/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.4718
# Epoch 35: val_loss did not improve from 4.45775
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.4717 - val_loss: 4.6436
# Epoch 36/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.4614
# Epoch 36: val_loss did not improve from 4.45775
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.4614 - val_loss: 4.5508
# Epoch 36: early stopping
# Repetition 2 model training started ...
# Epoch 1/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 30.3035
# Epoch 1: val_loss improved from inf to 6.44487, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 30.2542 - val_loss: 6.4449
# Epoch 2/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 8.5091
# Epoch 2: val_loss improved from 6.44487 to 4.43265, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 8.5090 - val_loss: 4.4327
# Epoch 3/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 6.8046
# Epoch 3: val_loss improved from 4.43265 to 3.75967, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.8049 - val_loss: 3.7597
# Epoch 4/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 5.9073
# Epoch 4: val_loss improved from 3.75967 to 3.41751, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.9078 - val_loss: 3.4175
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.3229
# Epoch 5: val_loss improved from 3.41751 to 3.15341, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.3228 - val_loss: 3.1534
# Epoch 6/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.8710
# Epoch 6: val_loss improved from 3.15341 to 2.98376, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.8701 - val_loss: 2.9838
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.5403
# Epoch 7: val_loss improved from 2.98376 to 2.86081, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.5403 - val_loss: 2.8608
# Epoch 8/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.3021
# Epoch 8: val_loss improved from 2.86081 to 2.79057, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 31ms/step - loss: 4.3007 - val_loss: 2.7906
# Epoch 9/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.1017
# Epoch 9: val_loss did not improve from 2.79057
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.1017 - val_loss: 2.7999
# Epoch 10/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.9125
# Epoch 10: val_loss improved from 2.79057 to 2.64729, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.9126 - val_loss: 2.6473
# Epoch 11/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.7973
# Epoch 11: val_loss did not improve from 2.64729
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.7973 - val_loss: 2.6486
# Epoch 12/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.6746
# Epoch 12: val_loss improved from 2.64729 to 2.51241, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6747 - val_loss: 2.5124
# Epoch 13/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.5680
# Epoch 13: val_loss did not improve from 2.51241
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5680 - val_loss: 2.6234
# Epoch 14/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.4701
# Epoch 14: val_loss improved from 2.51241 to 2.44616, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4686 - val_loss: 2.4462
# Epoch 15/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.3880
# Epoch 15: val_loss did not improve from 2.44616
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3868 - val_loss: 2.6646
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3279
# Epoch 16: val_loss did not improve from 2.44616
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3277 - val_loss: 2.4971
# Epoch 17/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.2441
# Epoch 17: val_loss did not improve from 2.44616
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.2460 - val_loss: 2.5544
# Epoch 18/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1993
# Epoch 18: val_loss improved from 2.44616 to 2.38936, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1983 - val_loss: 2.3894
# Epoch 19/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.1326
# Epoch 19: val_loss did not improve from 2.38936
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1319 - val_loss: 2.3977
# Epoch 20/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.0722
# Epoch 20: val_loss did not improve from 2.38936
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0723 - val_loss: 2.4727
# Epoch 21/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.0337
# Epoch 21: val_loss improved from 2.38936 to 2.32573, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0332 - val_loss: 2.3257
# Epoch 22/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.9827
# Epoch 22: val_loss did not improve from 2.32573
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9827 - val_loss: 2.4853
# Epoch 23/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.9459
# Epoch 23: val_loss did not improve from 2.32573
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9444 - val_loss: 2.3602
# Epoch 24/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.8944
# Epoch 24: val_loss did not improve from 2.32573
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8935 - val_loss: 2.4338
# Epoch 25/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.8758
# Epoch 25: val_loss did not improve from 2.32573
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8745 - val_loss: 2.4604
# Epoch 26/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.8285
# Epoch 26: val_loss did not improve from 2.32573
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8281 - val_loss: 2.4612
# Epoch 26: early stopping
# Repetition 3 model training started ...
# Epoch 1/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 32.9585
# Epoch 1: val_loss improved from inf to 9.76213, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 32.9344 - val_loss: 9.7621
# Epoch 2/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 8.3910
# Epoch 2: val_loss improved from 9.76213 to 7.15155, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 8.3895 - val_loss: 7.1516
# Epoch 3/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 6.6674
# Epoch 3: val_loss improved from 7.15155 to 5.79724, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.6678 - val_loss: 5.7972
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.8162
# Epoch 4: val_loss improved from 5.79724 to 5.16467, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.8162 - val_loss: 5.1647
# Epoch 5/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 5.2318
# Epoch 5: val_loss improved from 5.16467 to 4.70311, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.2297 - val_loss: 4.7031
# Epoch 6/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.8250
# Epoch 6: val_loss improved from 4.70311 to 4.39613, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.8247 - val_loss: 4.3961
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.5042
# Epoch 7: val_loss improved from 4.39613 to 4.21334, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.5042 - val_loss: 4.2133
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.2681
# Epoch 8: val_loss improved from 4.21334 to 4.07514, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.2679 - val_loss: 4.0751
# Epoch 9/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.0534
# Epoch 9: val_loss improved from 4.07514 to 3.84459, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.0548 - val_loss: 3.8446
# Epoch 10/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.8852
# Epoch 10: val_loss improved from 3.84459 to 3.73785, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.8848 - val_loss: 3.7379
# Epoch 11/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.7444
# Epoch 11: val_loss did not improve from 3.73785
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.7441 - val_loss: 3.7761
# Epoch 12/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.6246
# Epoch 12: val_loss improved from 3.73785 to 3.60477, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6249 - val_loss: 3.6048
# Epoch 13/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.5185
# Epoch 13: val_loss did not improve from 3.60477
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5185 - val_loss: 3.6699
# Epoch 14/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.4245
# Epoch 14: val_loss improved from 3.60477 to 3.52278, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.4242 - val_loss: 3.5228
# Epoch 15/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.3488
# Epoch 15: val_loss did not improve from 3.52278
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3490 - val_loss: 3.5251
# Epoch 16/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.2595
# Epoch 16: val_loss improved from 3.52278 to 3.49638, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.2589 - val_loss: 3.4964
# Epoch 17/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1804
# Epoch 17: val_loss improved from 3.49638 to 3.36950, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1809 - val_loss: 3.3695
# Epoch 18/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1322
# Epoch 18: val_loss did not improve from 3.36950
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1317 - val_loss: 3.4207
# Epoch 19/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.0792
# Epoch 19: val_loss did not improve from 3.36950
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0782 - val_loss: 3.3812
# Epoch 20/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.0219
# Epoch 20: val_loss did not improve from 3.36950
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0234 - val_loss: 3.4784
# Epoch 21/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.9711
# Epoch 21: val_loss did not improve from 3.36950
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9710 - val_loss: 3.4164
# Epoch 22/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9168
# Epoch 22: val_loss improved from 3.36950 to 3.35258, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 2.9171 - val_loss: 3.3526
# Epoch 23/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.8803
# Epoch 23: val_loss did not improve from 3.35258
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8813 - val_loss: 3.4431
# Epoch 24/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.8296
# Epoch 24: val_loss improved from 3.35258 to 3.28027, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8320 - val_loss: 3.2803
# Epoch 25/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.7996
# Epoch 25: val_loss did not improve from 3.28027
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7993 - val_loss: 3.4233
# Epoch 26/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.7675
# Epoch 26: val_loss did not improve from 3.28027
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7666 - val_loss: 3.3686
# Epoch 27/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.7241
# Epoch 27: val_loss improved from 3.28027 to 3.27993, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 2.7240 - val_loss: 3.2799
# Epoch 28/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.6876
# Epoch 28: val_loss did not improve from 3.27993
# 1229/1229 [==============================] - 40s 32ms/step - loss: 2.6872 - val_loss: 3.4702
# Epoch 29/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.6489
# Epoch 29: val_loss improved from 3.27993 to 3.24629, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 2.6489 - val_loss: 3.2463
# Epoch 30/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.6231
# Epoch 30: val_loss did not improve from 3.24629
# 1229/1229 [==============================] - 40s 33ms/step - loss: 2.6217 - val_loss: 3.3498
# Epoch 31/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.5954
# Epoch 31: val_loss did not improve from 3.24629
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.5950 - val_loss: 3.5150
# Epoch 32/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.5720
# Epoch 32: val_loss did not improve from 3.24629
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.5720 - val_loss: 3.3517
# Epoch 33/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.5380
# Epoch 33: val_loss did not improve from 3.24629
# 1229/1229 [==============================] - 40s 32ms/step - loss: 2.5379 - val_loss: 3.5484
# Epoch 34/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.5137
# Epoch 34: val_loss did not improve from 3.24629
# 1229/1229 [==============================] - 40s 32ms/step - loss: 2.5142 - val_loss: 3.6110
# Epoch 34: early stopping
# Repetition 4 model training started ...
# Epoch 1/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 28.4245
# Epoch 1: val_loss improved from inf to 7.65891, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 28.4038 - val_loss: 7.6589
# Epoch 2/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 8.0226
# Epoch 2: val_loss improved from 7.65891 to 6.04329, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 8.0208 - val_loss: 6.0433
# Epoch 3/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 6.4792
# Epoch 3: val_loss improved from 6.04329 to 5.36075, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.4794 - val_loss: 5.3608
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.5767
# Epoch 4: val_loss improved from 5.36075 to 4.92474, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.5771 - val_loss: 4.9247
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.9987
# Epoch 5: val_loss improved from 4.92474 to 4.67605, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 5.0001 - val_loss: 4.6761
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.6053
# Epoch 6: val_loss improved from 4.67605 to 4.55590, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.6051 - val_loss: 4.5559
# Epoch 7/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.3164
# Epoch 7: val_loss improved from 4.55590 to 4.31818, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.3149 - val_loss: 4.3182
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.0708
# Epoch 8: val_loss improved from 4.31818 to 4.25586, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.0705 - val_loss: 4.2559
# Epoch 9/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.8794
# Epoch 9: val_loss improved from 4.25586 to 4.10205, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.8801 - val_loss: 4.1020
# Epoch 10/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.7478
# Epoch 10: val_loss improved from 4.10205 to 4.00062, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.7479 - val_loss: 4.0006
# Epoch 11/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.6107
# Epoch 11: val_loss did not improve from 4.00062
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6100 - val_loss: 4.0007
# Epoch 12/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.4941
# Epoch 12: val_loss improved from 4.00062 to 3.94573, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4932 - val_loss: 3.9457
# Epoch 13/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4203
# Epoch 13: val_loss improved from 3.94573 to 3.87990, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4205 - val_loss: 3.8799
# Epoch 14/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.3179
# Epoch 14: val_loss did not improve from 3.87990
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3176 - val_loss: 3.8931
# Epoch 15/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.2448
# Epoch 15: val_loss improved from 3.87990 to 3.82933, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.2446 - val_loss: 3.8293
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.1896
# Epoch 16: val_loss improved from 3.82933 to 3.73246, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.1896 - val_loss: 3.7325
# Epoch 17/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1086
# Epoch 17: val_loss did not improve from 3.73246
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1078 - val_loss: 3.7752
# Epoch 18/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.0557
# Epoch 18: val_loss did not improve from 3.73246
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0562 - val_loss: 3.8272
# Epoch 19/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9975
# Epoch 19: val_loss did not improve from 3.73246
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9971 - val_loss: 3.7487
# Epoch 20/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9643
# Epoch 20: val_loss did not improve from 3.73246
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9643 - val_loss: 3.7395
# Epoch 21/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9077
# Epoch 21: val_loss did not improve from 3.73246
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9073 - val_loss: 3.7506
# Epoch 21: early stopping
# Repetition 5 model training started ...
# Epoch 1/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 34.9322
# Epoch 1: val_loss improved from inf to 7.52395, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 34.9274 - val_loss: 7.5240
# Epoch 2/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 8.8336
# Epoch 2: val_loss improved from 7.52395 to 5.49214, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 8.8328 - val_loss: 5.4921
# Epoch 3/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 6.9852
# Epoch 3: val_loss improved from 5.49214 to 4.47032, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 6.9840 - val_loss: 4.4703
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.9729
# Epoch 4: val_loss improved from 4.47032 to 4.12590, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 5.9726 - val_loss: 4.1259
# Epoch 5/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.3374
# Epoch 5: val_loss improved from 4.12590 to 3.91643, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.3374 - val_loss: 3.9164
# Epoch 6/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.9013
# Epoch 6: val_loss improved from 3.91643 to 3.46070, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.9015 - val_loss: 3.4607
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.5498
# Epoch 7: val_loss improved from 3.46070 to 3.40853, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.5496 - val_loss: 3.4085
# Epoch 8/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.2824
# Epoch 8: val_loss improved from 3.40853 to 3.21459, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.2824 - val_loss: 3.2146
# Epoch 9/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.0808
# Epoch 9: val_loss improved from 3.21459 to 3.15601, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.0803 - val_loss: 3.1560
# Epoch 10/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.9164
# Epoch 10: val_loss improved from 3.15601 to 3.00049, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.9167 - val_loss: 3.0005
# Epoch 11/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.7768
# Epoch 11: val_loss improved from 3.00049 to 2.96803, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.7768 - val_loss: 2.9680
# Epoch 12/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.6451
# Epoch 12: val_loss did not improve from 2.96803
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6444 - val_loss: 2.9751
# Epoch 13/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.5556
# Epoch 13: val_loss improved from 2.96803 to 2.79946, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5559 - val_loss: 2.7995
# Epoch 14/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.4596
# Epoch 14: val_loss did not improve from 2.79946
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4596 - val_loss: 2.8224
# Epoch 15/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3911
# Epoch 15: val_loss did not improve from 2.79946
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3911 - val_loss: 2.9327
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2966
# Epoch 16: val_loss did not improve from 2.79946
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.2966 - val_loss: 3.0596
# Epoch 17/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.2442
# Epoch 17: val_loss improved from 2.79946 to 2.70982, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.2452 - val_loss: 2.7098
# Epoch 18/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1808
# Epoch 18: val_loss did not improve from 2.70982
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1812 - val_loss: 2.7571
# Epoch 19/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.1248
# Epoch 19: val_loss improved from 2.70982 to 2.55908, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1248 - val_loss: 2.5591
# Epoch 20/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.0622
# Epoch 20: val_loss did not improve from 2.55908
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0623 - val_loss: 2.7665
# Epoch 21/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.0225
# Epoch 21: val_loss did not improve from 2.55908
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0227 - val_loss: 2.5853
# Epoch 22/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.9768
# Epoch 22: val_loss did not improve from 2.55908
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9775 - val_loss: 2.6298
# Epoch 23/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9207
# Epoch 23: val_loss did not improve from 2.55908
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9224 - val_loss: 2.6114
# Epoch 24/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.8912
# Epoch 24: val_loss improved from 2.55908 to 2.50813, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8917 - val_loss: 2.5081
# Epoch 25/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.8600
# Epoch 25: val_loss did not improve from 2.50813
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8600 - val_loss: 2.5159
# Epoch 26/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8037
# Epoch 26: val_loss improved from 2.50813 to 2.49510, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8037 - val_loss: 2.4951
# Epoch 27/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.7842
# Epoch 27: val_loss improved from 2.49510 to 2.40071, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7842 - val_loss: 2.4007
# Epoch 28/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.7438
# Epoch 28: val_loss did not improve from 2.40071
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7436 - val_loss: 2.4927
# Epoch 29/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.7055
# Epoch 29: val_loss did not improve from 2.40071
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.7077 - val_loss: 2.7202
# Epoch 30/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.6661
# Epoch 30: val_loss did not improve from 2.40071
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.6658 - val_loss: 2.5396
# Epoch 31/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.6506
# Epoch 31: val_loss did not improve from 2.40071
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.6506 - val_loss: 2.6284
# Epoch 32/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.6141
# Epoch 32: val_loss did not improve from 2.40071
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.6141 - val_loss: 2.6496
# Epoch 32: early stopping
# Repetition 6 model training started ...
# Epoch 1/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 31.3455
# Epoch 1: val_loss improved from inf to 5.54852, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 31.3401 - val_loss: 5.5485
# Epoch 2/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 8.5316
# Epoch 2: val_loss improved from 5.54852 to 4.24532, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 8.5322 - val_loss: 4.2453
# Epoch 3/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.8423
# Epoch 3: val_loss improved from 4.24532 to 3.34129, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.8413 - val_loss: 3.3413
# Epoch 4/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 5.9185
# Epoch 4: val_loss improved from 3.34129 to 2.98984, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 5.9165 - val_loss: 2.9898
# Epoch 5/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.3624
# Epoch 5: val_loss improved from 2.98984 to 2.75215, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 5.3625 - val_loss: 2.7522
# Epoch 6/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.9474
# Epoch 6: val_loss improved from 2.75215 to 2.61917, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.9486 - val_loss: 2.6192
# Epoch 7/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.6609
# Epoch 7: val_loss improved from 2.61917 to 2.46232, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.6594 - val_loss: 2.4623
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.4082
# Epoch 8: val_loss improved from 2.46232 to 2.40461, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 4.4082 - val_loss: 2.4046
# Epoch 9/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.2065
# Epoch 9: val_loss improved from 2.40461 to 2.31648, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.2072 - val_loss: 2.3165
# Epoch 10/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.0342
# Epoch 10: val_loss improved from 2.31648 to 2.20767, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.0358 - val_loss: 2.2077
# Epoch 11/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.9065
# Epoch 11: val_loss improved from 2.20767 to 2.16579, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.9066 - val_loss: 2.1658
# Epoch 12/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.7956
# Epoch 12: val_loss improved from 2.16579 to 2.06519, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.7956 - val_loss: 2.0652
# Epoch 13/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.6814
# Epoch 13: val_loss did not improve from 2.06519
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6823 - val_loss: 2.1169
# Epoch 14/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.5766
# Epoch 14: val_loss did not improve from 2.06519
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5759 - val_loss: 2.1242
# Epoch 15/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.4941
# ...
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.5623 - val_loss: 3.6552
# Epoch 33: early stopping
# Repetition 9 model training started ...
# Epoch 1/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 30.6007
# Epoch 1: val_loss improved from inf to 7.30259, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 30.5806 - val_loss: 7.3026
# Epoch 2/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 8.3813
# Epoch 2: val_loss improved from 7.30259 to 4.97241, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 8.3786 - val_loss: 4.9724
# Epoch 3/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 6.7115
# Epoch 3: val_loss improved from 4.97241 to 4.14736, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.7095 - val_loss: 4.1474
# Epoch 4/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 5.7979
# Epoch 4: val_loss improved from 4.14736 to 3.64592, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 5.8011 - val_loss: 3.6459
# Epoch 5/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.2191
# Epoch 5: val_loss improved from 3.64592 to 3.41315, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 5.2191 - val_loss: 3.4132
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.8311
# Epoch 6: val_loss improved from 3.41315 to 3.15101, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.8309 - val_loss: 3.1510
# Epoch 7/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.5151
# Epoch 7: val_loss improved from 3.15101 to 3.08258, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.5151 - val_loss: 3.0826
# Epoch 8/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.2959
# Epoch 8: val_loss improved from 3.08258 to 2.99614, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.2952 - val_loss: 2.9961
# Epoch 9/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 4.0858
# Epoch 9: val_loss improved from 2.99614 to 2.96765, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.0842 - val_loss: 2.9677
# Epoch 10/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.9409
# Epoch 10: val_loss improved from 2.96765 to 2.85061, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.9412 - val_loss: 2.8506
# Epoch 11/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.8092
# Epoch 11: val_loss improved from 2.85061 to 2.76358, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.8093 - val_loss: 2.7636
# Epoch 12/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.6975
# Epoch 12: val_loss did not improve from 2.76358
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6973 - val_loss: 2.7741
# Epoch 13/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.5934
# Epoch 13: val_loss improved from 2.76358 to 2.70596, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5933 - val_loss: 2.7060
# Epoch 14/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.5121
# Epoch 14: val_loss did not improve from 2.70596
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5118 - val_loss: 2.7518
# Epoch 15/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.4223
# Epoch 15: val_loss did not improve from 2.70596
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4214 - val_loss: 2.7955
# Epoch 16/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3538
# Epoch 16: val_loss did not improve from 2.70596
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3538 - val_loss: 2.7270
# Epoch 17/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2898
# Epoch 17: val_loss did not improve from 2.70596
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.2896 - val_loss: 2.7728
# Epoch 18/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.2204
# Epoch 18: val_loss improved from 2.70596 to 2.61800, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 40s 32ms/step - loss: 3.2202 - val_loss: 2.6180
# Epoch 19/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1449
# Epoch 19: val_loss did not improve from 2.61800
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1451 - val_loss: 2.9543
# Epoch 20/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1151
# Epoch 20: val_loss improved from 2.61800 to 2.51699, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1151 - val_loss: 2.5170
# Epoch 21/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.0660
# Epoch 21: val_loss did not improve from 2.51699
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0655 - val_loss: 2.6442
# Epoch 22/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.0267
# Epoch 22: val_loss did not improve from 2.51699
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0242 - val_loss: 2.5280
# Epoch 23/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9638
# Epoch 23: val_loss did not improve from 2.51699
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9638 - val_loss: 2.5908
# Epoch 24/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 2.9354
# Epoch 24: val_loss did not improve from 2.51699
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9346 - val_loss: 2.6318
# Epoch 25/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8829
# Epoch 25: val_loss did not improve from 2.51699
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8826 - val_loss: 2.5892
# Epoch 25: early stopping
# Repetition 10 model training started ...
# Epoch 1/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 31.8461
# Epoch 1: val_loss improved from inf to 7.67376, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 43s 34ms/step - loss: 31.7894 - val_loss: 7.6738
# Epoch 2/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 8.6050
# Epoch 2: val_loss improved from 7.67376 to 5.45312, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 8.6015 - val_loss: 5.4531
# Epoch 3/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.8174
# Epoch 3: val_loss improved from 5.45312 to 4.43218, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 6.8179 - val_loss: 4.4322
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.8275
# Epoch 4: val_loss improved from 4.43218 to 3.83058, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.8276 - val_loss: 3.8306
# Epoch 5/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 5.2427
# Epoch 5: val_loss improved from 3.83058 to 3.53386, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 5.2416 - val_loss: 3.5339
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.8411
# Epoch 6: val_loss improved from 3.53386 to 3.30980, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.8408 - val_loss: 3.3098
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.5164
# Epoch 7: val_loss improved from 3.30980 to 3.12056, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.5161 - val_loss: 3.1206
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.2788
# Epoch 8: val_loss improved from 3.12056 to 2.98886, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.2797 - val_loss: 2.9889
# Epoch 9/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.0897
# Epoch 9: val_loss improved from 2.98886 to 2.94443, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 4.0897 - val_loss: 2.9444
# Epoch 10/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.9127
# Epoch 10: val_loss improved from 2.94443 to 2.84361, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.9129 - val_loss: 2.8436
# Epoch 11/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.7837
# Epoch 11: val_loss improved from 2.84361 to 2.79503, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.7829 - val_loss: 2.7950
# Epoch 12/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.6578
# Epoch 12: val_loss improved from 2.79503 to 2.77543, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.6565 - val_loss: 2.7754
# Epoch 13/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.5719
# Epoch 13: val_loss improved from 2.77543 to 2.69684, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.5717 - val_loss: 2.6968
# Epoch 14/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4652
# Epoch 14: val_loss improved from 2.69684 to 2.62531, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.4649 - val_loss: 2.6253
# Epoch 15/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3871
# Epoch 15: val_loss did not improve from 2.62531
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3866 - val_loss: 2.6518
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3210
# Epoch 16: val_loss improved from 2.62531 to 2.56601, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.3207 - val_loss: 2.5660
# Epoch 17/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2557
# Epoch 17: val_loss did not improve from 2.56601
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.2554 - val_loss: 2.6065
# Epoch 18/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1786
# Epoch 18: val_loss did not improve from 2.56601
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1781 - val_loss: 2.7013
# Epoch 19/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1361
# Epoch 19: val_loss did not improve from 2.56601
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.1359 - val_loss: 2.6224
# Epoch 20/200
# 1225/1229 [============================>.] - ETA: 0s - loss: 3.0776
# Epoch 20: val_loss improved from 2.56601 to 2.51713, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0756 - val_loss: 2.5171
# Epoch 21/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.0267
# Epoch 21: val_loss improved from 2.51713 to 2.48562, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_10/best_model_repitition_10.h5
# 1229/1229 [==============================] - 39s 32ms/step - loss: 3.0265 - val_loss: 2.4856
# Epoch 22/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.9898
# Epoch 22: val_loss did not improve from 2.48562
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9895 - val_loss: 2.5708
# Epoch 23/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9386
# Epoch 23: val_loss did not improve from 2.48562
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9385 - val_loss: 2.5072
# Epoch 24/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9060
# Epoch 24: val_loss did not improve from 2.48562
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.9055 - val_loss: 2.5522
# Epoch 25/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8603
# Epoch 25: val_loss did not improve from 2.48562
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8606 - val_loss: 2.5751
# Epoch 26/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8317
# Epoch 26: val_loss did not improve from 2.48562
# 1229/1229 [==============================] - 39s 32ms/step - loss: 2.8316 - val_loss: 2.5470
# Epoch 26: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 53
#      49     val_loss_hist.append(history.history['val_loss'])
#      52 # Saving model training and validation loss history after all repetitions
# ---> 53 np.save(os.path.join(output_folder, 'train_loss_hist.npy'), np.array(train_loss_hist))
#      54 np.save(os.path.join(output_folder, 'val_loss_hist.npy'), np.array(val_loss_hist))
#      56 # Plot training and validation history for all repetitions
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (10,) + inhomogeneous part.

# %%
# summary of training and validation results
best_train_loss_MSE = np.zeros(num_fold)
best_val_loss_MSE = np.zeros(num_fold)

for i in range(num_fold):
    best_val_loss_MSE[i] = np.min(val_loss_hist[i])
    idx = np.argmin(val_loss_hist[i])
    best_train_loss_MSE[i] = train_loss_hist[i][idx]
    print('Model {0}  -- train loss: {1:.2f}, validation loss: {2:.2f} (RMSE)'.format(i+1, np.sqrt(best_train_loss_MSE[i]), np.sqrt(best_val_loss_MSE[i])))
print('The mean train loss (RMSE) for all models is {0:.2f}'.format(np.mean(np.sqrt(best_train_loss_MSE))))
print('The mean validation loss (RMSE) for all models is {0:.2f}'.format(np.mean(np.sqrt(best_val_loss_MSE))))
# Out:
# Model 1  -- train loss: 1.62, validation loss: 2.11 (RMSE)
# Model 2  -- train loss: 1.74, validation loss: 1.53 (RMSE)
# Model 3  -- train loss: 1.63, validation loss: 1.80 (RMSE)
# Model 4  -- train loss: 1.79, validation loss: 1.93 (RMSE)
# Model 5  -- train loss: 1.67, validation loss: 1.55 (RMSE)
# Model 6  -- train loss: 1.77, validation loss: 1.37 (RMSE)
# Model 7  -- train loss: 1.68, validation loss: 1.89 (RMSE)
# Model 8  -- train loss: 1.65, validation loss: 1.90 (RMSE)
# Model 9  -- train loss: 1.76, validation loss: 1.59 (RMSE)
# Model 10  -- train loss: 1.74, validation loss: 1.58 (RMSE)
# The mean train loss (RMSE) for all models is 1.70
# The mean validation loss (RMSE) for all models is 1.72

# %% [markdown]
# ### Model testing

# %%
# load testing data
times_test = np.load(os.path.join(data_folder,"times_test.npy"),allow_pickle=True)
print("times_test.shape:", times_test.shape)

with h5py.File(data_path,'r') as f:

    # read in the data
    images_log_test = f['test']['images_log'][...]
    pv_log_test = f['test']['pv_log'][...]

# process image data
images_log_test = (images_log_test/255.0).astype('float32')
pv_log_test = pv_log_test.astype('float32')

print("images_log_test.shape:",images_log_test.shape)
print("pv_log_test.shape:",pv_log_test.shape)
# Out:
# times_test.shape: (14003,)
# images_log_test.shape: (14003, 64, 64, 3)
# pv_log_test.shape: (14003,)

# %%
# evaluate model on the test set and generate predictions
loss = np.zeros((num_fold,len(times_test)))
prediction = np.zeros((num_fold,len(times_test)))

for i in range(num_fold):
    # define model path
    print("loading repetition {0} model ...".format(i+1))
    model_path = os.path.join(output_folder,'repetition_'+str(i+1),'best_model_repitition_'+str(i+1)+'.h5')
    # load the trained model
    model = keras.models.load_model(model_path)
    
    # model evaluation
    print("evaluating performance for the model".format(i+1))
    loss[i] = model.evaluate(x=images_log_test, y=pv_log_test, batch_size=200, verbose=1)
    
    # generate prediction
    print("generating predictions for the model".format(i+1))
    prediction[i] = np.squeeze(model.predict(images_log_test, batch_size=200, verbose=1))

# saving predictions from each model
np.save(os.path.join(output_folder,'test_predictions.npy'),prediction)

# using the ensemble mean of the 10 models as the final prediction 
print('-'*50)
print("model ensembling ...")
prediction_ensemble = np.mean(prediction,axis=0)
loss_ensemble = np.sqrt(np.mean((prediction_ensemble-pv_log_test)**2))
print("the test set RMSE is {0:.3f} for the ensemble model".format(loss_ensemble))
# Out:
# loading repetition 1 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.8898
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 2 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.7631
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 3 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.3815
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 4 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.6322
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 5 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.9134
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 6 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.7853
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 7 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.9679
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 8 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.9042
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 9 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.9102
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# loading repetition 10 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 4ms/step - loss: 5.7911
# generating predictions for the model
# 71/71 [==============================] - 0s 3ms/step
# --------------------------------------------------
# model ensembling ...
# the test set RMSE is 2.321 for the ensemble model

# %%
# formulate sunny and cloudy test days
sunny_dates = [(2017,9,15),(2017,10,6),(2017,10,22),
               (2018,2,16),(2018,6,12),(2018,6,23),
               (2019,1,25),(2019,6,23),(2019,7,14),(2019,10,14)]
cloudy_dates = [(2017,6,24),(2017,9,20),(2017,10,11),
                (2018,1,25),(2018,3,9),(2018,10,4),
                (2019,5,27),(2019,6,28),(2019,8,10),(2019,10,19)]

sunny_dates_test = [datetime.date(day[0],day[1],day[2]) for day in sunny_dates]
cloudy_dates_test = [datetime.date(day[0],day[1],day[2]) for day in cloudy_dates]

dates_test = np.asarray([times.date() for times in times_test])

## generate mask for the sunny days
mask = np.zeros(len(pv_log_test),dtype=bool)
for i in sunny_dates_test:
    mask[np.where(dates_test==i)[0]]=1

## apply the mask to the dataset
times_test_sunny = times_test[mask]
pv_log_test_sunny = pv_log_test[mask]
images_log_test_sunny = images_log_test[mask]
prediction_ensemble_sunny = prediction_ensemble[mask]
print("times_test_sunny.shape:",times_test_sunny.shape)

times_test_cloudy = times_test[~mask]
pv_log_test_cloudy = pv_log_test[~mask]
images_log_test_cloudy = images_log_test[~mask]
prediction_ensemble_cloudy = prediction_ensemble[~mask]
print("times_test_cloudy.shape:",times_test_cloudy.shape)
# Out:
# times_test_sunny.shape: (6986,)
# times_test_cloudy.shape: (7017,)

# %%
# RMSE for sunny and cloudy days individually
rmse_sunny = np.sqrt(np.mean(np.square((prediction_ensemble_sunny-pv_log_test_sunny))))
rmse_cloudy = np.sqrt(np.mean(np.square((prediction_ensemble_cloudy-pv_log_test_cloudy))))
rmse_overall = np.sqrt((rmse_sunny**2*len(pv_log_test_sunny)+rmse_cloudy**2*len(pv_log_test_cloudy))/(len(pv_log_test)))

print("test set sunny days RMSE: {0:.3f}".format(rmse_sunny))
print("test set cloudy days RMSE: {0:.3f}".format(rmse_cloudy))
print("test set overall RMSE: {0:.3f}".format(rmse_overall))
# Out:
# test set sunny days RMSE: 0.511
# test set cloudy days RMSE: 3.238
# test set overall RMSE: 2.321

# %%
# MAE for sunny and cloudy days individually
mae_sunny = np.mean(np.abs((prediction_ensemble_sunny-pv_log_test_sunny)))
mae_cloudy = np.mean(np.abs((prediction_ensemble_cloudy-pv_log_test_cloudy)))
mae_overall = (mae_cloudy*len(pv_log_test_cloudy) + mae_sunny*len(pv_log_test_sunny))/(len(pv_log_test))

print("test set sunny days MAE: {0:.3f}".format(mae_sunny))
print("test set cloudy days MAE: {0:.3f}".format(mae_cloudy))
print("test set overall MAE: {0:.3f}".format(mae_overall))
# Out:
# test set sunny days MAE: 0.414
# test set cloudy days MAE: 2.204
# test set overall MAE: 1.311

# %%
# R² for sunny and cloudy days individually
r2_sunny = 1 - (np.sum(np.square(prediction_ensemble_sunny - pv_log_test_sunny)) / 
                np.sum(np.square(pv_log_test_sunny - np.mean(pv_log_test_sunny))))
r2_cloudy = 1 - (np.sum(np.square(prediction_ensemble_cloudy - pv_log_test_cloudy)) / 
                 np.sum(np.square(pv_log_test_cloudy - np.mean(pv_log_test_cloudy))))
r2_overall = 1 - (np.sum(np.square(np.concatenate([prediction_ensemble_sunny, prediction_ensemble_cloudy]) - 
                                   np.concatenate([pv_log_test_sunny, pv_log_test_cloudy]))) / 
                  np.sum(np.square(np.concatenate([pv_log_test_sunny, pv_log_test_cloudy]) - 
                                   np.mean(np.concatenate([pv_log_test_sunny, pv_log_test_cloudy])))))

print("test set sunny days R²: {0:.3f}".format(r2_sunny))
print("test set cloudy days R²: {0:.3f}".format(r2_cloudy))
print("test set overall R²: {0:.3f}".format(r2_overall))
# Out:
# test set sunny days R²: 0.995
# test set cloudy days R²: 0.815
# test set overall R²: 0.908

# %%
# EVS for sunny and cloudy days individually
evs_sunny = 1 - (np.var(prediction_ensemble_sunny - pv_log_test_sunny) / 
                 np.var(pv_log_test_sunny))
evs_cloudy = 1 - (np.var(prediction_ensemble_cloudy - pv_log_test_cloudy) / 
                  np.var(pv_log_test_cloudy))
evs_overall = 1 - (np.var(np.concatenate([prediction_ensemble_sunny, prediction_ensemble_cloudy]) - 
                          np.concatenate([pv_log_test_sunny, pv_log_test_cloudy])) / 
                   np.var(np.concatenate([pv_log_test_sunny, pv_log_test_cloudy])))

print("test set sunny days EVS: {0:.3f}".format(evs_sunny))
print("test set cloudy days EVS: {0:.3f}".format(evs_cloudy))
print("test set overall EVS: {0:.3f}".format(evs_overall))
# Out:
# test set sunny days EVS: 0.997
# test set cloudy days EVS: 0.822
# test set overall EVS: 0.912

# %%
# visualization of nowcast predictions
dates_test = np.array([dtinfo.date() for dtinfo in times_test])
hours_test = np.array([dtinfo.time() for dtinfo in times_test])

f,axarr = plt.subplots(10,2,sharex=False, sharey = True)
xfmt = mdates.DateFormatter('%H')
fmt_date = datetime.date(2000,1,1)

blue = '#67AFD2'
grey =  '#B6B1A9'

for i,date in enumerate(sunny_dates_test):
    ax = axarr[i,0]
    date_mask = (dates_test == date)
    hours_xaxis= [datetime.datetime.combine(fmt_date, hour) for hour in hours_test[date_mask]] 
    
    rmse = np.sqrt(np.mean(np.square((pv_log_test[date_mask]-prediction_ensemble[date_mask]))))
    mae = np.mean(np.abs((pv_log_test[date_mask]-prediction_ensemble[date_mask])))
    
    ax.plot(hours_xaxis, pv_log_test[date_mask], linewidth = 1,color=grey)
    ax.fill_between(hours_xaxis, 0, pv_log_test[date_mask], color=grey, alpha=.2, label = 'Ground truth')
    ax.plot(hours_xaxis, prediction_ensemble[date_mask],linewidth = 1,label = 'SUNSET nowcast',color=blue,markerfacecolor="None")
    ax.set_ylabel('PV output (kW)')
    ax.xaxis.set_major_formatter(xfmt)
    ax.text(0.75,0.85,'Sunny_'+str(i+1), transform=ax.transAxes)
    ax.text(0.05,0.75,"RMSE: {0:.2f}\nMAE: {1:.2f}".format(rmse,mae),transform=ax.transAxes)

for i,date in enumerate(cloudy_dates_test):
    ax = axarr[i,1]
    date_mask = (dates_test == date)
    hours_xaxis= [datetime.datetime.combine(fmt_date, hour) for hour in hours_test[date_mask]] 
    
    rmse = np.sqrt(np.mean(np.square((pv_log_test[date_mask]-prediction_ensemble[date_mask]))))
    mae = np.mean(np.abs((pv_log_test[date_mask]-prediction_ensemble[date_mask])))
    
    ax.plot(hours_xaxis, pv_log_test[date_mask], linewidth = 1,color=grey)
    ax.fill_between(hours_xaxis, 0, pv_log_test[date_mask], color=grey, alpha=.2, label = 'Ground truth')
    ax.plot(hours_xaxis, prediction_ensemble[date_mask],linewidth = 1,label = 'SUNSET nowcast',color=blue,markerfacecolor="None")
    ax.set_ylabel('PV output (kW)')
    ax.xaxis.set_major_formatter(xfmt)
    ax.text(0.75,0.85,'Cloudy_'+str(i+1), transform=ax.transAxes)
    ax.text(0.05,0.75,"RMSE: {0:.2f}\nMAE: {1:.2f}".format(rmse,mae),transform=ax.transAxes)

    
axarr[0,0].set_ylim(0, 30)
axarr[0,0].legend(bbox_to_anchor= [1.15,1.3], loc = 'upper center', ncol = 3)
axarr[-1,0].set_xlabel('Hour of day')
axarr[-1,1].set_xlabel('Hour of day')

f.set_size_inches(10,25)    
plt.show()
