# %% [markdown]
# ### Libraries and data loading

# %%
# import libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import datetime
import itertools
import h5py
import matplotlib.dates as mdates

# %matplotlib inline
# Out:
# 2024-12-18 16:08:44.427100: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 16:08:44.722642: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 16:08:44.845418: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 16:08:45.764653: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-12-18 16:08:45.764769: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-12-18 16:08:45.764776: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# check tensorflow version
print("tensorflow version:", tf.__version__)
# check available gpu
gpus =  tf.config.list_physical_devices('GPU')
print("available gpus:", gpus)
# limit the gpu usage, prevent it from allocating all gpu memory for a simple model
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# check number of cpus available
print("available cpus:", os.cpu_count())
# Out:
# tensorflow version: 2.10.0
# available gpus: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# available cpus: 112
# 2024-12-18 16:08:48.865090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:08:48.872186: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:08:48.872456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
import tensorflow as tf
sys_details = tf.sysconfig.get_build_info()
sys_details["cuda_version"]
# Out:
# '11.2'

# %%
# define the data location and load data

data_folder = os.path.join("data")
data_path = os.path.join(data_folder, "2017_2019_images_pv_processed.hdf5")

# !change model name for different models!
model_name = 'SUNSET_nowcast_CNN_Attention_2017_2019_data'
output_folder = os.path.join("model_output", model_name)
if os.path.isdir(output_folder)==False:
    os.makedirs(output_folder)

print("data_folder:", data_folder)
print("data_path:", data_path)
print("output_folder:", output_folder)
# Out:
# data_folder: data
# data_path: data/2017_2019_images_pv_processed.hdf5
# output_folder: model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data

# %%
# generate handler for the hdf5 data
forecast_dataset = h5py.File(data_path, 'r')

# show structure of the hdf5 data
def get_all(name):
    if name!=None:
        print(forecast_dataset[name])
    
forecast_dataset.visit(get_all)
# Out:
# <HDF5 group "/test" (2 members)>
# <HDF5 dataset "images_log": shape (14003, 64, 64, 3), type "|u1">
# <HDF5 dataset "pv_log": shape (14003,), type "<f8">
# <HDF5 group "/trainval" (2 members)>
# <HDF5 dataset "images_log": shape (349372, 64, 64, 3), type "|u1">
# <HDF5 dataset "pv_log": shape (349372,), type "<f8">

# %%
print('-'*50)
# get the input dimension for constructing the model
img_side_len = forecast_dataset['trainval']['images_log'].shape[1]

num_log_term = forecast_dataset['trainval']['images_log'].shape[1]

num_color_channel = forecast_dataset['trainval']['images_log'].shape[3]
image_input_dim = [img_side_len,img_side_len,num_color_channel]

print("image side length:", img_side_len)

print("number of log terms:", num_log_term)

print("number of color channels:", num_color_channel)
print("input image dimension:", image_input_dim)

# load time stamps into the memory
times_trainval = np.load(os.path.join(data_folder,"times_trainval.npy"),allow_pickle=True)
print("times_trainval.shape:", times_trainval.shape)

# read through the dataset once in order to cache it but not store it into the memory
## read the data by batch
num_samples = len(times_trainval)
batch_size = num_samples//5
indices = np.arange(num_samples)
print('-'*50)
print('data reading start...')
for i in range(int(num_samples / batch_size) + 1):
    start_time = time.time()
    start_idx = (i * batch_size) % num_samples
    idxs = indices[start_idx:start_idx + batch_size]
    _ = forecast_dataset['trainval']['images_log'][idxs]
    _ = forecast_dataset['trainval']['pv_log'][idxs]
    end_time = time.time()
    print("batch {0} samples: {1} to {2}, {3:.2f}% finished, processing time {4:.2f}s"
          .format(i+1, idxs[0],idxs[-1],(idxs[-1]/num_samples)*100,(end_time-start_time)))

# temporially close the dataset, will use "with" statement to open it when we use it
forecast_dataset.close()
# Out:
# --------------------------------------------------
# image side length: 64
# number of log terms: 64
# number of color channels: 3
# input image dimension: [64, 64, 3]
# times_trainval.shape: (349372,)
# --------------------------------------------------
# data reading start...
# batch 1 samples: 0 to 69873, 20.00% finished, processing time 0.86s
# batch 2 samples: 69874 to 139747, 40.00% finished, processing time 0.85s
# batch 3 samples: 139748 to 209621, 60.00% finished, processing time 0.85s
# batch 4 samples: 209622 to 279495, 80.00% finished, processing time 0.84s
# batch 5 samples: 279496 to 349369, 100.00% finished, processing time 0.85s
# batch 6 samples: 349370 to 349371, 100.00% finished, processing time 0.00s

# %% [markdown]
# ### Input data pipeline helper functions

# %%
# day block shuffling of the time stamps, and return shuffled indices
def day_block_shuffle(times_trainval):
    
    # Only keep the date of each time point
    dates_trainval = np.zeros_like(times_trainval, dtype=datetime.date)
    for i in range(len(times_trainval)):
        dates_trainval[i] = times_trainval[i].date()

    # Chop the indices into blocks, so that each block contains the indices of the same day
    unique_dates = np.unique(dates_trainval)
    blocks = []
    for i in range(len(unique_dates)):
        blocks.append(np.where(dates_trainval == unique_dates[i])[0])

    # shuffle the blocks, and chain it back together
    np.random.seed(1)
    np.random.shuffle(blocks)
    shuffled_indices = np.asarray(list(itertools.chain.from_iterable(blocks)))

    return shuffled_indices

# %%
# a cross validation generator function for spliting the dayblock shuffled indices into training and validation
def cv_split(split_data, fold_index, num_fold):
    '''
    input:
    split_data: the dayblock shuffled indices to be splitted
    fold_index: the ith fold chosen as the validation, used for generating the seed for random shuffling
    num_fold: N-fold cross validation
    output:
    data_train: the train data indices
    data_val: the validation data indices
    '''
    # randomly divides into a training set and a validation set
    num_samples = len(split_data)
    indices = np.arange(num_samples)

    # finding training and validation indices
    val_mask = np.zeros(len(indices), dtype=bool)
    val_mask[int(fold_index / num_fold * num_samples):int((fold_index + 1) / num_fold * num_samples)] = True
    val_indices = indices[val_mask]
    train_indices = indices[np.logical_not(val_mask)]

    # shuffle indices
    np.random.seed(fold_index)
    np.random.shuffle(train_indices)
    np.random.shuffle(val_indices)
    
    data_train = split_data[train_indices]
    data_val = split_data[val_indices]

    return data_train,data_val

# %%
# a mapping function from the indices to the corresponding features and labels 
def data_loader(hdf5_data_path,sample_idx,batch_size=256):
    '''
    input:
    hdf5_data_path: path to hdf5 data file
    sample_idx: 
        for training and validation:
            dayblock shuffled indices with cross-validation split into training and validation
            either training or validation indices will be input
        for testing: the indices are not shuffled
    is_trainval: a flag, True for trainig and validation
    output:
    dataset: dataset for training, validation
    '''

    def mapping_func_py(hdf5_data_path,sample_idx):
        '''
        mapping indices to corresponding images and pviance data in hdf5 (python expression)
        '''
        # convert EagerTensor to str or numpy array
        hdf5_data_path = hdf5_data_path.numpy().decode() 
        # sort the sample indices as hdf5 requires increasing order index for data retrieval
        sample_idx = sorted(sample_idx.numpy())

        with h5py.File(hdf5_data_path,'r') as f:

            # read in the data
            images_log = f['trainval']['images_log'][sample_idx]
            pv_log = f['trainval']['pv_log'][sample_idx]

            # normalize image data to [0,1]
            images_log = tf.image.convert_image_dtype(images_log, tf.float32)
            
            # convert pv data to tf.tensor
            pv_log = tf.convert_to_tensor(pv_log, dtype=tf.float32)
            
            return images_log, pv_log

    def mapping_func_tf(hdf5_data_path,sample_idx):
        '''
        a wrapper mapping function to get the nested data structure 
        the output type of tf.py_function cannot be a nested sequence when using a tf.py_function with the tf.data API
        '''
        images_log, pv_log = tf.py_function(func=mapping_func_py,
                                                           inp=[hdf5_data_path, sample_idx], 
                                                           Tout=(tf.float32, tf.float32))
        return images_log, pv_log
    
    
    # create the indices dataset
    idx_ds = tf.data.Dataset.from_tensor_slices(sample_idx)
    # shuffle and batch the indices
    idx_ds = idx_ds.shuffle(buffer_size = idx_ds.cardinality().numpy(),seed=0)
    idx_ds = idx_ds.batch(batch_size).repeat().prefetch(tf.data.experimental.AUTOTUNE)
    
    # indices dataset mapping to images and pviance data
    # returning dataset with the following nested structure: (images_log, pv_log), pv_pred
    dataset = idx_ds.map(lambda x: mapping_func_tf(hdf5_data_path,x),
                         num_parallel_calls=tf.data.experimental.AUTOTUNE)
    
    return dataset

# %% [markdown]
# ### Model architecture

# %%
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dropout, Dense, Reshape, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Model characteristics
num_filters = 24
kernel_size = [3, 3]
pool_size = [2, 2]
strides = 2
dense_size = 1024
drop_rate = 0.4

# define training time parameters
num_epochs = 200 #(The maximum epoches set to 200 and there might be early stopping depends on validation loss)
num_fold = 10 # 10-fold cross-validation
batch_size = 256
learning_rate = 3e-06

def spatial_attention(input_feature):
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = layers.Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(1, kernel_size=(7, 7), padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, attention])

# Model architecture with Attention
def sunset_model():
    ## Input
    x_in = keras.Input(shape=(64, 64, 3))  # Update shape to match input data (RGB)

    ## 1st convolution block with attention
    x = Conv2D(12, kernel_size, padding="same", activation='relu')(x_in)  # Adjust filters
    x = BatchNormalization()(x)
    x = spatial_attention(x)  # Add Channel Attention
    x = MaxPooling2D(pool_size, strides)(x)

    ## 2nd convolution block with attention
    x = Conv2D(24, kernel_size, padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = spatial_attention(x)  # Add Channel Attention
    x = MaxPooling2D(pool_size, strides)(x)

    # Flatten the convolution output for connection with Dense layers
    x = Flatten()(x)

    # Fully connected layers
    x = Dense(dense_size, activation='relu')(x)
    x = Dropout(drop_rate)(x)
    x = Dense(dense_size, activation='relu')(x)
    x = Dropout(drop_rate)(x)

    ## Regression to prediction target
    y_out = keras.layers.Dense(units=1)(x)

    # Construct the model
    model = keras.Model(inputs=x_in, outputs=y_out)

    # Compile the model with an optimizer
    optimizer = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

    return model

# Example input dimensions (update based on your dataset)
image_input_dim = (64, 64, 24)  # Example: 64x64 images with 24 channels (time-series images)

# Build the model
model = sunset_model()

# Display the model architecture
model.summary()
# Out:
# 2024-12-18 16:09:22.126077: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 16:09:22.134098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:09:22.134457: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:09:22.134673: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:09:23.029131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:09:23.029857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:09:23.030172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-12-18 16:09:23.030412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22288 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 12)   336         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 12)  48          ['conv2d[0][0]']
#  alization)
#
#  lambda (Lambda)                (None, 64, 64, 1)    0           ['batch_normalization[0][0]']
#
#  lambda_1 (Lambda)              (None, 64, 64, 1)    0           ['batch_normalization[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 2)    0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 1)    99          ['concatenate[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 12)   0           ['batch_normalization[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 12)   0           ['multiply[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 24)   2616        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 24)  96          ['conv2d_2[0][0]']
#  rmalization)
#
#  lambda_2 (Lambda)              (None, 32, 32, 1)    0           ['batch_normalization_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 32, 32, 1)    0           ['batch_normalization_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 2)    0           ['lambda_2[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 1)    99          ['concatenate_1[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 32, 24)   0           ['batch_normalization_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 24)  0           ['multiply_1[0][0]']
#
#  flatten (Flatten)              (None, 6144)         0           ['max_pooling2d_1[0][0]']
#
#  dense (Dense)                  (None, 1024)         6292480     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         1049600     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            1025        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7,346,399
# Trainable params: 7,346,327
# Non-trainable params: 72
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model training and validation

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import os
import numpy as np
import matplotlib.pyplot as plt

# generate dayblock shuffled indices
indices_dayblock_shuffled = day_block_shuffle(times_trainval)

# initialize loss history list
train_loss_hist = []
val_loss_hist = []



for i in range(num_fold):

    # construct and compile model for each repetition to reinitialize the model weights
    keras.backend.clear_session()
    model = sunset_model()
    model.compile(optimizer=keras.optimizers.Adam(learning_rate), loss='mse')

    # implementing 10-fold cross-validation
    print('Repetition {0} model training started ...'.format(i+1))

    # creating folder for saving model checkpoint
    save_directory = os.path.join(output_folder, 'repetition_' + str(i+1))
    if not os.path.exists(save_directory):
        os.makedirs(save_directory)

    # training and validation data preparation
    ## generate indices dataset for training and validation
    indices_train, indices_val = cv_split(indices_dayblock_shuffled, i, num_fold)
    ## load data from dataloader
    ds_train_batched = data_loader(data_path, indices_train)
    ds_val_batched = data_loader(data_path, indices_val, batch_size=500)

     # define callbacks for training
    ## early stopping rule: if the validation loss stop decreasing for 5 consecutive epoches
    earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    ## model check point: save model checkpoint for later use
    checkpoint = keras.callbacks.ModelCheckpoint(os.path.join(save_directory,'best_model_repitition_'+str(i+1)+'.h5'), 
                                monitor='val_loss', mode='min', save_best_only=True, verbose=1)

    # training the model and record training and validation loss
    history = model.fit(ds_train_batched, epochs=num_epochs, steps_per_epoch=len(indices_train)//batch_size+1,
                               verbose=1, callbacks=[earlystop,checkpoint], validation_data=ds_val_batched,
                              validation_steps=len(indices_val)//batch_size+1)
    train_loss_hist.append(history.history['loss'])
    val_loss_hist.append(history.history['val_loss'])
    

# Saving model training and validation loss history after all repetitions
np.save(os.path.join(output_folder, 'train_loss_hist.npy'), np.array(train_loss_hist))
np.save(os.path.join(output_folder, 'val_loss_hist.npy'), np.array(val_loss_hist))

# Plot training and validation history for all repetitions
for i in range(num_fold):
    plt.plot(train_loss_hist[i], label=f'train Repetition {i+1}')
    plt.plot(val_loss_hist[i], label=f'validation Repetition {i+1}')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Repetitions')
plt.show()
# Out:
# Repetition 1 model training started ...
# Epoch 1/200
# 2024-12-18 16:09:46.677466: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-12-18 16:09:49.035340: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1229/1229 [==============================] - ETA: 0s - loss: 31.2126
# Epoch 1: val_loss improved from inf to 9.54623, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 51s 37ms/step - loss: 31.2126 - val_loss: 9.5462
# Epoch 2/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 8.4737
# Epoch 2: val_loss improved from 9.54623 to 7.38739, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 44s 36ms/step - loss: 8.4681 - val_loss: 7.3874
# Epoch 3/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 6.7645
# Epoch 3: val_loss improved from 7.38739 to 6.41363, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.7640 - val_loss: 6.4136
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.8916
# Epoch 4: val_loss improved from 6.41363 to 5.82984, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.8912 - val_loss: 5.8298
# Epoch 5/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.3350
# Epoch 5: val_loss improved from 5.82984 to 5.52890, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.3350 - val_loss: 5.5289
# Epoch 6/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.9186
# Epoch 6: val_loss improved from 5.52890 to 5.22549, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.9186 - val_loss: 5.2255
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.6022
# Epoch 7: val_loss improved from 5.22549 to 5.20227, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.6023 - val_loss: 5.2023
# Epoch 8/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.3514
# Epoch 8: val_loss improved from 5.20227 to 4.96940, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.3522 - val_loss: 4.9694
# Epoch 9/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.1597
# Epoch 9: val_loss did not improve from 4.96940
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.1597 - val_loss: 5.0596
# Epoch 10/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.9918
# Epoch 10: val_loss improved from 4.96940 to 4.94361, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.9919 - val_loss: 4.9436
# Epoch 11/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.8561
# Epoch 11: val_loss did not improve from 4.94361
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.8556 - val_loss: 4.9770
# Epoch 12/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.7241
# Epoch 12: val_loss improved from 4.94361 to 4.79168, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_1/best_model_repitition_1.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.7233 - val_loss: 4.7917
# Epoch 13/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.6208
# Epoch 13: val_loss did not improve from 4.79168
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.6215 - val_loss: 5.0022
# Epoch 14/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.5161
# Epoch 14: val_loss did not improve from 4.79168
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5159 - val_loss: 4.9333
# Epoch 15/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.4429
# Epoch 15: val_loss did not improve from 4.79168
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4429 - val_loss: 4.7971
# Epoch 16/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3625
# Epoch 16: val_loss did not improve from 4.79168
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.3625 - val_loss: 4.8769
# Epoch 17/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3012
# Epoch 17: val_loss did not improve from 4.79168
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.3012 - val_loss: 4.9542
# Epoch 17: early stopping
# Repetition 2 model training started ...
# Epoch 1/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 31.5794
# Epoch 1: val_loss improved from inf to 7.12128, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 47s 37ms/step - loss: 31.5606 - val_loss: 7.1213
# Epoch 2/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 9.3149
# Epoch 2: val_loss improved from 7.12128 to 4.71154, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 9.3145 - val_loss: 4.7115
# Epoch 3/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 7.1779
# Epoch 3: val_loss improved from 4.71154 to 4.00280, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 7.1771 - val_loss: 4.0028
# Epoch 4/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.1131
# Epoch 4: val_loss improved from 4.00280 to 3.64902, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.1125 - val_loss: 3.6490
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.4428
# Epoch 5: val_loss improved from 3.64902 to 3.41636, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.4428 - val_loss: 3.4164
# Epoch 6/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.0029
# Epoch 6: val_loss improved from 3.41636 to 3.24127, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.0029 - val_loss: 3.2413
# Epoch 7/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.6569
# Epoch 7: val_loss did not improve from 3.24127
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.6572 - val_loss: 3.2544
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.4025
# Epoch 8: val_loss improved from 3.24127 to 3.13236, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.4022 - val_loss: 3.1324
# Epoch 9/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.1903
# Epoch 9: val_loss improved from 3.13236 to 3.09160, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.1903 - val_loss: 3.0916
# Epoch 10/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.0282
# Epoch 10: val_loss improved from 3.09160 to 2.97352, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.0281 - val_loss: 2.9735
# Epoch 11/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.8689
# Epoch 11: val_loss improved from 2.97352 to 2.89874, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.8697 - val_loss: 2.8987
# Epoch 12/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.7655
# Epoch 12: val_loss did not improve from 2.89874
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.7655 - val_loss: 2.9057
# Epoch 13/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.6490
# Epoch 13: val_loss did not improve from 2.89874
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.6483 - val_loss: 3.0548
# Epoch 14/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.5566
# Epoch 14: val_loss improved from 2.89874 to 2.76940, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5566 - val_loss: 2.7694
# Epoch 15/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4793
# Epoch 15: val_loss did not improve from 2.76940
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4792 - val_loss: 2.8784
# Epoch 16/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.3943
# Epoch 16: val_loss did not improve from 2.76940
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.3950 - val_loss: 2.8714
# Epoch 17/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3121
# Epoch 17: val_loss did not improve from 2.76940
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.3128 - val_loss: 2.8698
# Epoch 18/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.2536
# Epoch 18: val_loss improved from 2.76940 to 2.61134, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.2536 - val_loss: 2.6113
# Epoch 19/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1809
# Epoch 19: val_loss did not improve from 2.61134
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1807 - val_loss: 2.7484
# Epoch 20/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1393
# Epoch 20: val_loss did not improve from 2.61134
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1396 - val_loss: 2.7002
# Epoch 21/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.0707
# Epoch 21: val_loss improved from 2.61134 to 2.59728, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.0707 - val_loss: 2.5973
# Epoch 22/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.0295
# Epoch 22: val_loss did not improve from 2.59728
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.0293 - val_loss: 2.6848
# Epoch 23/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.9952
# Epoch 23: val_loss improved from 2.59728 to 2.50622, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_2/best_model_repitition_2.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9951 - val_loss: 2.5062
# Epoch 24/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9295
# Epoch 24: val_loss did not improve from 2.50622
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9295 - val_loss: 2.5985
# Epoch 25/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8941
# Epoch 25: val_loss did not improve from 2.50622
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.8947 - val_loss: 2.6982
# Epoch 26/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.8572
# Epoch 26: val_loss did not improve from 2.50622
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.8572 - val_loss: 2.7714
# Epoch 27/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8108
# Epoch 27: val_loss did not improve from 2.50622
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.8107 - val_loss: 2.7838
# Epoch 28/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.7757
# Epoch 28: val_loss did not improve from 2.50622
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.7763 - val_loss: 2.5071
# Epoch 28: early stopping
# Repetition 3 model training started ...
# Epoch 1/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 51.6984
# Epoch 1: val_loss improved from inf to 12.85812, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 47s 37ms/step - loss: 51.6904 - val_loss: 12.8581
# Epoch 2/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 10.7455
# Epoch 2: val_loss improved from 12.85812 to 8.92126, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 44s 36ms/step - loss: 10.7444 - val_loss: 8.9213
# Epoch 3/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 7.8267
# Epoch 3: val_loss improved from 8.92126 to 6.90003, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 44s 36ms/step - loss: 7.8260 - val_loss: 6.9000
# Epoch 4/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.5251
# Epoch 4: val_loss improved from 6.90003 to 5.98066, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.5238 - val_loss: 5.9807
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.8073
# Epoch 5: val_loss improved from 5.98066 to 5.42426, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.8054 - val_loss: 5.4243
# Epoch 6/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.3214
# Epoch 6: val_loss improved from 5.42426 to 5.05922, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.3214 - val_loss: 5.0592
# Epoch 7/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.9679
# Epoch 7: val_loss improved from 5.05922 to 4.86669, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.9679 - val_loss: 4.8667
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.6883
# Epoch 8: val_loss improved from 4.86669 to 4.57402, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.6881 - val_loss: 4.5740
# Epoch 9/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.4494
# Epoch 9: val_loss improved from 4.57402 to 4.39675, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.4494 - val_loss: 4.3968
# Epoch 10/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.2720
# Epoch 10: val_loss improved from 4.39675 to 4.31738, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.2705 - val_loss: 4.3174
# Epoch 11/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.0864
# Epoch 11: val_loss improved from 4.31738 to 4.19394, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.0861 - val_loss: 4.1939
# Epoch 12/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.9419
# Epoch 12: val_loss improved from 4.19394 to 4.09248, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.9419 - val_loss: 4.0925
# Epoch 13/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.8228
# Epoch 13: val_loss improved from 4.09248 to 4.00742, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.8227 - val_loss: 4.0074
# Epoch 14/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.7057
# Epoch 14: val_loss improved from 4.00742 to 3.98036, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.7057 - val_loss: 3.9804
# Epoch 15/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.6128
# Epoch 15: val_loss improved from 3.98036 to 3.84584, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.6134 - val_loss: 3.8458
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.5139
# Epoch 16: val_loss did not improve from 3.84584
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5134 - val_loss: 3.9134
# Epoch 17/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4260
# Epoch 17: val_loss improved from 3.84584 to 3.74662, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4264 - val_loss: 3.7466
# Epoch 18/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3508
# Epoch 18: val_loss did not improve from 3.74662
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.3508 - val_loss: 3.7957
# Epoch 19/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2863
# Epoch 19: val_loss improved from 3.74662 to 3.73534, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.2857 - val_loss: 3.7353
# Epoch 20/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.2225
# Epoch 20: val_loss did not improve from 3.73534
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.2225 - val_loss: 3.8239
# Epoch 21/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1574
# Epoch 21: val_loss did not improve from 3.73534
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.1573 - val_loss: 3.7761
# Epoch 22/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1250
# Epoch 22: val_loss improved from 3.73534 to 3.69824, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1241 - val_loss: 3.6982
# Epoch 23/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.0362
# Epoch 23: val_loss did not improve from 3.69824
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.0362 - val_loss: 3.7979
# Epoch 24/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9964
# Epoch 24: val_loss improved from 3.69824 to 3.59752, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_3/best_model_repitition_3.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9964 - val_loss: 3.5975
# Epoch 25/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.9502
# Epoch 25: val_loss did not improve from 3.59752
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9498 - val_loss: 3.6163
# Epoch 26/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.9032
# Epoch 26: val_loss did not improve from 3.59752
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9034 - val_loss: 3.7556
# Epoch 27/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.8619
# Epoch 27: val_loss did not improve from 3.59752
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.8613 - val_loss: 3.7373
# Epoch 28/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8132
# Epoch 28: val_loss did not improve from 3.59752
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.8134 - val_loss: 3.7680
# Epoch 29/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.7715
# Epoch 29: val_loss did not improve from 3.59752
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.7715 - val_loss: 3.6846
# Epoch 29: early stopping
# Repetition 4 model training started ...
# Epoch 1/200
# 1229/1229 [==============================] - ETA: 0s - loss: 30.0107
# Epoch 1: val_loss improved from inf to 8.23592, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 46s 37ms/step - loss: 30.0107 - val_loss: 8.2359
# Epoch 2/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 9.4062
# Epoch 2: val_loss improved from 8.23592 to 6.32531, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 9.4052 - val_loss: 6.3253
# Epoch 3/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 7.2879
# Epoch 3: val_loss improved from 6.32531 to 5.52262, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 7.2884 - val_loss: 5.5226
# Epoch 4/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.2728
# Epoch 4: val_loss improved from 5.52262 to 5.11355, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.2733 - val_loss: 5.1136
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.6346
# Epoch 5: val_loss improved from 5.11355 to 4.88909, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.6367 - val_loss: 4.8891
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.1820
# Epoch 6: val_loss improved from 4.88909 to 4.72956, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.1820 - val_loss: 4.7296
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.8029
# Epoch 7: val_loss did not improve from 4.72956
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.8026 - val_loss: 4.7345
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.5304
# Epoch 8: val_loss did not improve from 4.72956
# 1229/1229 [==============================] - 42s 35ms/step - loss: 4.5300 - val_loss: 4.7778
# Epoch 9/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.3205
# Epoch 9: val_loss did not improve from 4.72956
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.3205 - val_loss: 4.7515
# Epoch 10/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.1290
# Epoch 10: val_loss improved from 4.72956 to 4.52227, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_4/best_model_repitition_4.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.1291 - val_loss: 4.5223
# Epoch 11/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.9624
# Epoch 11: val_loss did not improve from 4.52227
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.9622 - val_loss: 4.7945
# Epoch 12/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.8319
# Epoch 12: val_loss did not improve from 4.52227
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.8314 - val_loss: 4.7605
# Epoch 13/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.7215
# Epoch 13: val_loss did not improve from 4.52227
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.7213 - val_loss: 4.7342
# Epoch 14/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.6204
# Epoch 14: val_loss did not improve from 4.52227
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.6202 - val_loss: 4.6275
# Epoch 15/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.5183
# Epoch 15: val_loss did not improve from 4.52227
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5180 - val_loss: 4.7736
# Epoch 15: early stopping
# Repetition 5 model training started ...
# Epoch 1/200
# 1229/1229 [==============================] - ETA: 0s - loss: 28.4822
# Epoch 1: val_loss improved from inf to 6.78145, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 47s 37ms/step - loss: 28.4822 - val_loss: 6.7814
# Epoch 2/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 8.9496
# Epoch 2: val_loss improved from 6.78145 to 4.96435, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 8.9483 - val_loss: 4.9644
# Epoch 3/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 7.0686
# Epoch 3: val_loss improved from 4.96435 to 4.23925, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 7.0677 - val_loss: 4.2392
# Epoch 4/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.1299
# Epoch 4: val_loss improved from 4.23925 to 3.97740, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.1292 - val_loss: 3.9774
# Epoch 5/200
# 1229/1229 [==============================] - ETA: 0s - loss: 5.5743
# Epoch 5: val_loss improved from 3.97740 to 3.86728, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 5.5743 - val_loss: 3.8673
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.1375
# Epoch 6: val_loss improved from 3.86728 to 3.60265, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.1374 - val_loss: 3.6027
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.8366
# Epoch 7: val_loss did not improve from 3.60265
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.8362 - val_loss: 3.8151
# Epoch 8/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.5618
# Epoch 8: val_loss did not improve from 3.60265
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.5618 - val_loss: 3.6982
# Epoch 9/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.3461
# Epoch 9: val_loss did not improve from 3.60265
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.3455 - val_loss: 3.6811
# Epoch 10/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.1823
# Epoch 10: val_loss improved from 3.60265 to 3.51016, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.1828 - val_loss: 3.5102
# Epoch 11/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.0385
# Epoch 11: val_loss improved from 3.51016 to 3.48596, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.0393 - val_loss: 3.4860
# Epoch 12/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.8705
# Epoch 12: val_loss did not improve from 3.48596
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.8699 - val_loss: 3.6288
# Epoch 13/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.7904
# Epoch 13: val_loss did not improve from 3.48596
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.7904 - val_loss: 3.5429
# Epoch 14/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.6749
# Epoch 14: val_loss improved from 3.48596 to 3.40716, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.6747 - val_loss: 3.4072
# Epoch 15/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.5732
# Epoch 15: val_loss did not improve from 3.40716
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5725 - val_loss: 3.6771
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.4952
# Epoch 16: val_loss did not improve from 3.40716
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4950 - val_loss: 3.7493
# Epoch 17/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4153
# Epoch 17: val_loss did not improve from 3.40716
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4152 - val_loss: 3.8719
# Epoch 18/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3346
# Epoch 18: val_loss did not improve from 3.40716
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.3353 - val_loss: 3.6043
# Epoch 19/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.2644
# Epoch 19: val_loss improved from 3.40716 to 3.23407, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_5/best_model_repitition_5.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.2642 - val_loss: 3.2341
# Epoch 20/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.2029
# Epoch 20: val_loss did not improve from 3.23407
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.2027 - val_loss: 3.5204
# Epoch 21/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.1392
# Epoch 21: val_loss did not improve from 3.23407
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1390 - val_loss: 3.5007
# Epoch 22/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.0899
# Epoch 22: val_loss did not improve from 3.23407
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.0908 - val_loss: 3.6482
# Epoch 23/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.0499
# Epoch 23: val_loss did not improve from 3.23407
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.0522 - val_loss: 3.9144
# Epoch 24/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9948
# Epoch 24: val_loss did not improve from 3.23407
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9948 - val_loss: 3.5322
# Epoch 24: early stopping
# Repetition 6 model training started ...
# Epoch 1/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 45.8067
# Epoch 1: val_loss improved from inf to 7.25403, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 47s 37ms/step - loss: 45.7706 - val_loss: 7.2540
# Epoch 2/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 10.1742
# Epoch 2: val_loss improved from 7.25403 to 5.54443, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 10.1741 - val_loss: 5.5444
# Epoch 3/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 8.1267
# Epoch 3: val_loss improved from 5.54443 to 4.45389, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 8.1262 - val_loss: 4.4539
# Epoch 4/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.9583
# Epoch 4: val_loss improved from 4.45389 to 3.79608, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.9569 - val_loss: 3.7961
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.1558
# Epoch 5: val_loss improved from 3.79608 to 3.34189, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.1567 - val_loss: 3.3419
# Epoch 6/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 5.5918
# Epoch 6: val_loss improved from 3.34189 to 3.04867, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 5.5920 - val_loss: 3.0487
# Epoch 7/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.1455
# Epoch 7: val_loss improved from 3.04867 to 2.84727, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.1456 - val_loss: 2.8473
# Epoch 8/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.8083
# Epoch 8: val_loss improved from 2.84727 to 2.75895, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.8080 - val_loss: 2.7589
# Epoch 9/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.5496
# Epoch 9: val_loss improved from 2.75895 to 2.65230, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.5507 - val_loss: 2.6523
# Epoch 10/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.3404
# Epoch 10: val_loss improved from 2.65230 to 2.52521, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.3434 - val_loss: 2.5252
# Epoch 11/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.1588
# Epoch 11: val_loss improved from 2.52521 to 2.50992, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.1593 - val_loss: 2.5099
# Epoch 12/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.0205
# Epoch 12: val_loss improved from 2.50992 to 2.41696, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.0205 - val_loss: 2.4170
# Epoch 13/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.8806
# Epoch 13: val_loss improved from 2.41696 to 2.38980, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.8814 - val_loss: 2.3898
# Epoch 14/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.7853
# Epoch 14: val_loss did not improve from 2.38980
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.7848 - val_loss: 2.4130
# Epoch 15/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.6939
# Epoch 15: val_loss improved from 2.38980 to 2.32460, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.6939 - val_loss: 2.3246
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.5873
# Epoch 16: val_loss improved from 2.32460 to 2.31997, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5868 - val_loss: 2.3200
# Epoch 17/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.5256
# Epoch 17: val_loss improved from 2.31997 to 2.25002, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5256 - val_loss: 2.2500
# Epoch 18/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.4452
# Epoch 18: val_loss did not improve from 2.25002
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.4453 - val_loss: 2.2698
# Epoch 19/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3748
# Epoch 19: val_loss improved from 2.25002 to 2.21858, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.3748 - val_loss: 2.2186
# Epoch 20/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.3001
# Epoch 20: val_loss did not improve from 2.21858
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.3007 - val_loss: 2.2772
# Epoch 21/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2587
# Epoch 21: val_loss improved from 2.21858 to 2.19656, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.2588 - val_loss: 2.1966
# Epoch 22/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.1919
# Epoch 22: val_loss improved from 2.19656 to 2.15134, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_6/best_model_repitition_6.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1918 - val_loss: 2.1513
# Epoch 23/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.1439
# Epoch 23: val_loss did not improve from 2.15134
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1445 - val_loss: 2.1676
# Epoch 24/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.1024
# Epoch 24: val_loss did not improve from 2.15134
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.1012 - val_loss: 2.2375
# Epoch 25/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.0426
# Epoch 25: val_loss did not improve from 2.15134
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.0427 - val_loss: 2.1532
# Epoch 26/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.0105
# Epoch 26: val_loss did not improve from 2.15134
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.0105 - val_loss: 2.1584
# Epoch 27/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9637
# Epoch 27: val_loss did not improve from 2.15134
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9637 - val_loss: 2.1525
# Epoch 27: early stopping
# Repetition 7 model training started ...
# Epoch 1/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 29.1819
# Epoch 1: val_loss improved from inf to 7.46885, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 46s 36ms/step - loss: 29.1782 - val_loss: 7.4689
# Epoch 2/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 8.8640
# Epoch 2: val_loss improved from 7.46885 to 5.77282, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 8.8638 - val_loss: 5.7728
# Epoch 3/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 6.8622
# Epoch 3: val_loss improved from 5.77282 to 5.01921, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.8628 - val_loss: 5.0192
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.8465
# Epoch 4: val_loss improved from 5.01921 to 4.68086, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 5.8468 - val_loss: 4.6809
# Epoch 5/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.2129
# Epoch 5: val_loss improved from 4.68086 to 4.46139, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.2111 - val_loss: 4.4614
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.8131
# Epoch 6: val_loss improved from 4.46139 to 4.33395, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.8128 - val_loss: 4.3339
# Epoch 7/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.4611
# Epoch 7: val_loss did not improve from 4.33395
# 1229/1229 [==============================] - 42s 35ms/step - loss: 4.4604 - val_loss: 4.4312
# Epoch 8/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.2288
# Epoch 8: val_loss improved from 4.33395 to 4.30196, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.2274 - val_loss: 4.3020
# Epoch 9/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.0006
# Epoch 9: val_loss improved from 4.30196 to 4.15010, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_7/best_model_repitition_7.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.0006 - val_loss: 4.1501
# Epoch 10/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.8524
# Epoch 10: val_loss did not improve from 4.15010
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.8519 - val_loss: 4.2741
# Epoch 11/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.7005
# Epoch 11: val_loss did not improve from 4.15010
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.7002 - val_loss: 4.3534
# Epoch 12/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.5829
# Epoch 12: val_loss did not improve from 4.15010
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5832 - val_loss: 4.3464
# Epoch 13/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.4534
# Epoch 13: val_loss did not improve from 4.15010
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4532 - val_loss: 4.3603
# Epoch 14/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3611
# Epoch 14: val_loss did not improve from 4.15010
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.3608 - val_loss: 4.4768
# Epoch 14: early stopping
# Repetition 8 model training started ...
# Epoch 1/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 42.0712
# Epoch 1: val_loss improved from inf to 14.10126, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 46s 36ms/step - loss: 42.0386 - val_loss: 14.1013
# Epoch 2/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 10.0692
# Epoch 2: val_loss improved from 14.10126 to 9.75116, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 10.0670 - val_loss: 9.7512
# Epoch 3/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 7.5116
# Epoch 3: val_loss improved from 9.75116 to 7.89522, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 7.5110 - val_loss: 7.8952
# Epoch 4/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 6.4022
# Epoch 4: val_loss improved from 7.89522 to 6.97514, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.4012 - val_loss: 6.9751
# Epoch 5/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 5.6790
# Epoch 5: val_loss improved from 6.97514 to 6.27807, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.6789 - val_loss: 6.2781
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.1832
# Epoch 6: val_loss improved from 6.27807 to 5.84897, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 5.1832 - val_loss: 5.8490
# Epoch 7/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.8490
# Epoch 7: val_loss improved from 5.84897 to 5.51404, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.8482 - val_loss: 5.5140
# Epoch 8/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.5565
# Epoch 8: val_loss improved from 5.51404 to 5.35654, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.5565 - val_loss: 5.3565
# Epoch 9/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 4.3210
# ...
# Epoch 15: val_loss improved from 4.47975 to 4.42604, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5356 - val_loss: 4.4260
# Epoch 16/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.4482
# Epoch 16: val_loss improved from 4.42604 to 4.37786, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.4478 - val_loss: 4.3779
# Epoch 17/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.3756
# Epoch 17: val_loss improved from 4.37786 to 4.29564, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.3754 - val_loss: 4.2956
# Epoch 18/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.3149
# Epoch 18: val_loss did not improve from 4.29564
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.3150 - val_loss: 4.3165
# Epoch 19/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.2514
# Epoch 19: val_loss improved from 4.29564 to 4.29216, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.2509 - val_loss: 4.2922
# Epoch 20/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.1920
# Epoch 20: val_loss improved from 4.29216 to 4.16871, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.1919 - val_loss: 4.1687
# Epoch 21/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.1410
# Epoch 21: val_loss improved from 4.16871 to 4.12299, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.1411 - val_loss: 4.1230
# Epoch 22/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.0802
# Epoch 22: val_loss improved from 4.12299 to 4.05316, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.0802 - val_loss: 4.0532
# Epoch 23/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.0247
# Epoch 23: val_loss did not improve from 4.05316
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.0250 - val_loss: 4.0742
# Epoch 24/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.9917
# Epoch 24: val_loss did not improve from 4.05316
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.9917 - val_loss: 4.0893
# Epoch 25/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.9396
# Epoch 25: val_loss improved from 4.05316 to 3.95944, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.9395 - val_loss: 3.9594
# Epoch 26/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.8972
# Epoch 26: val_loss did not improve from 3.95944
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.8973 - val_loss: 3.9862
# Epoch 27/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.8579
# Epoch 27: val_loss improved from 3.95944 to 3.90448, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.8576 - val_loss: 3.9045
# Epoch 28/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.8228
# Epoch 28: val_loss improved from 3.90448 to 3.87273, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.8228 - val_loss: 3.8727
# Epoch 29/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.7859
# Epoch 29: val_loss did not improve from 3.87273
# 1229/1229 [==============================] - 42s 34ms/step - loss: 2.7861 - val_loss: 3.9403
# Epoch 30/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.7607
# Epoch 30: val_loss did not improve from 3.87273
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.7611 - val_loss: 3.9087
# Epoch 31/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.7252
# Epoch 31: val_loss did not improve from 3.87273
# 1229/1229 [==============================] - 42s 34ms/step - loss: 2.7247 - val_loss: 3.9132
# Epoch 32/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.6927
# Epoch 32: val_loss did not improve from 3.87273
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.6925 - val_loss: 3.8918
# Epoch 33/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.6467
# Epoch 33: val_loss improved from 3.87273 to 3.82398, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.6465 - val_loss: 3.8240
# Epoch 34/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.6256
# Epoch 34: val_loss did not improve from 3.82398
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.6258 - val_loss: 3.9000
# Epoch 35/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.6064
# Epoch 35: val_loss improved from 3.82398 to 3.79023, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 2.6062 - val_loss: 3.7902
# Epoch 36/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.5780
# Epoch 36: val_loss did not improve from 3.79023
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.5783 - val_loss: 3.8203
# Epoch 37/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.5447
# Epoch 37: val_loss improved from 3.79023 to 3.76238, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.5447 - val_loss: 3.7624
# Epoch 38/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.5134
# Epoch 38: val_loss did not improve from 3.76238
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.5134 - val_loss: 3.7989
# Epoch 39/200
# 1229/1229 [==============================] - ETA: 0s - loss: 2.4926
# Epoch 39: val_loss improved from 3.76238 to 3.74851, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.4926 - val_loss: 3.7485
# Epoch 40/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.4706
# Epoch 40: val_loss improved from 3.74851 to 3.70515, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_8/best_model_repitition_8.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.4704 - val_loss: 3.7052
# Epoch 41/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 2.4359
# Epoch 41: val_loss did not improve from 3.70515
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.4359 - val_loss: 3.8016
# Epoch 42/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.4152
# Epoch 42: val_loss did not improve from 3.70515
# 1229/1229 [==============================] - 43s 35ms/step - loss: 2.4150 - val_loss: 3.7621
# Epoch 43/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 2.3933
# Epoch 43: val_loss did not improve from 3.70515
# 1229/1229 [==============================] - 42s 35ms/step - loss: 2.3935 - val_loss: 3.7116
# Epoch 44/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.3698
# Epoch 44: val_loss did not improve from 3.70515
# 1229/1229 [==============================] - 42s 34ms/step - loss: 2.3693 - val_loss: 3.7439
# Epoch 45/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 2.3448
# Epoch 45: val_loss did not improve from 3.70515
# 1229/1229 [==============================] - 42s 34ms/step - loss: 2.3454 - val_loss: 3.7385
# Epoch 45: early stopping
# Repetition 9 model training started ...
# Epoch 1/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 53.4699
# Epoch 1: val_loss improved from inf to 11.85724, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 46s 37ms/step - loss: 53.4620 - val_loss: 11.8572
# Epoch 2/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 11.1800
# Epoch 2: val_loss improved from 11.85724 to 7.37824, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 11.1773 - val_loss: 7.3782
# Epoch 3/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 8.4841
# Epoch 3: val_loss improved from 7.37824 to 5.91734, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 8.4819 - val_loss: 5.9173
# Epoch 4/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 7.1243
# Epoch 4: val_loss improved from 5.91734 to 5.08964, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 7.1238 - val_loss: 5.0896
# Epoch 5/200
# 1229/1229 [==============================] - ETA: 0s - loss: 6.2288
# Epoch 5: val_loss improved from 5.08964 to 4.40446, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 6.2288 - val_loss: 4.4045
# Epoch 6/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.5970
# Epoch 6: val_loss improved from 4.40446 to 4.09224, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 5.5974 - val_loss: 4.0922
# Epoch 7/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 5.1585
# Epoch 7: val_loss improved from 4.09224 to 3.72982, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 5.1584 - val_loss: 3.7298
# Epoch 8/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.8155
# Epoch 8: val_loss improved from 3.72982 to 3.53925, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 4.8147 - val_loss: 3.5393
# Epoch 9/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.5679
# Epoch 9: val_loss improved from 3.53925 to 3.39732, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.5679 - val_loss: 3.3973
# Epoch 10/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 4.3789
# Epoch 10: val_loss improved from 3.39732 to 3.28465, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 4.3788 - val_loss: 3.2847
# Epoch 11/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 4.2052
# Epoch 11: val_loss improved from 3.28465 to 3.18276, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 4.2052 - val_loss: 3.1828
# Epoch 12/200
# 1229/1229 [==============================] - ETA: 0s - loss: 4.0678
# Epoch 12: val_loss improved from 3.18276 to 3.09438, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 4.0678 - val_loss: 3.0944
# Epoch 13/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.9547
# Epoch 13: val_loss improved from 3.09438 to 3.06620, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.9544 - val_loss: 3.0662
# Epoch 14/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.8501
# Epoch 14: val_loss improved from 3.06620 to 3.00961, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.8493 - val_loss: 3.0096
# Epoch 15/200
# 1226/1229 [============================>.] - ETA: 0s - loss: 3.7613
# Epoch 15: val_loss did not improve from 3.00961
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.7609 - val_loss: 3.0175
# Epoch 16/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.6944
# Epoch 16: val_loss improved from 3.00961 to 2.88385, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.6945 - val_loss: 2.8838
# Epoch 17/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.6025
# Epoch 17: val_loss did not improve from 2.88385
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.6025 - val_loss: 2.8884
# Epoch 18/200
# 1228/1229 [============================>.] - ETA: 0s - loss: 3.5466
# Epoch 18: val_loss improved from 2.88385 to 2.85041, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.5463 - val_loss: 2.8504
# Epoch 19/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.4860
# Epoch 19: val_loss improved from 2.85041 to 2.82091, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 34ms/step - loss: 3.4860 - val_loss: 2.8209
# Epoch 20/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.4198
# Epoch 20: val_loss improved from 2.82091 to 2.78447, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.4200 - val_loss: 2.7845
# Epoch 21/200
# 1227/1229 [============================>.] - ETA: 0s - loss: 3.3634
# Epoch 21: val_loss improved from 2.78447 to 2.77361, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 42s 35ms/step - loss: 3.3630 - val_loss: 2.7736
# Epoch 22/200
# 1229/1229 [==============================] - ETA: 0s - loss: 3.3276
# Epoch 22: val_loss improved from 2.77361 to 2.73426, saving model to model_output/SUNSET_nowcast_CNN_Attention_2017_2019_data/repetition_9/best_model_repitition_9.h5
# 1229/1229 [==============================] - 43s 35ms/step - loss: 3.3276 - val_loss: 2.7343
# Epoch 23/200
#  535/1229 [============>.................] - ETA: 17s - loss: 3.2376

# %%
# summary of training and validation results
best_train_loss_MSE = np.zeros(num_fold)
best_val_loss_MSE = np.zeros(num_fold)
num_fold=8

for i in range(num_fold):
    best_val_loss_MSE[i] = np.min(val_loss_hist[i])
    idx = np.argmin(val_loss_hist[i])
    best_train_loss_MSE[i] = train_loss_hist[i][idx]
    print('Model {0}  -- train loss: {1:.2f}, validation loss: {2:.2f} (RMSE)'.format(i+1, np.sqrt(best_train_loss_MSE[i]), np.sqrt(best_val_loss_MSE[i])))
print('The mean train loss (RMSE) for all models is {0:.2f}'.format(np.mean(np.sqrt(best_train_loss_MSE))))
print('The mean validation loss (RMSE) for all models is {0:.2f}'.format(np.mean(np.sqrt(best_val_loss_MSE))))
# Out:
# Model 1  -- train loss: 1.93, validation loss: 2.19 (RMSE)
# Model 2  -- train loss: 1.73, validation loss: 1.58 (RMSE)
# Model 3  -- train loss: 1.73, validation loss: 1.90 (RMSE)
# Model 4  -- train loss: 2.03, validation loss: 2.13 (RMSE)
# Model 5  -- train loss: 1.81, validation loss: 1.80 (RMSE)
# Model 6  -- train loss: 1.79, validation loss: 1.47 (RMSE)
# Model 7  -- train loss: 2.00, validation loss: 2.04 (RMSE)
# Model 8  -- train loss: 1.57, validation loss: 1.92 (RMSE)
# The mean train loss (RMSE) for all models is 1.46
# The mean validation loss (RMSE) for all models is 1.50

# %% [markdown]
# ### Model testing

# %%
# load testing data
times_test = np.load(os.path.join(data_folder,"times_test.npy"),allow_pickle=True)
print("times_test.shape:", times_test.shape)

with h5py.File(data_path,'r') as f:

    # read in the data
    images_log_test = f['test']['images_log'][...]
    pv_log_test = f['test']['pv_log'][...]

# process image data
images_log_test = (images_log_test/255.0).astype('float32')
pv_log_test = pv_log_test.astype('float32')

print("images_log_test.shape:",images_log_test.shape)
print("pv_log_test.shape:",pv_log_test.shape)
# Out:
# times_test.shape: (14003,)
# images_log_test.shape: (14003, 64, 64, 3)
# pv_log_test.shape: (14003,)

# %%
# evaluate model on the test set and generate predictions
loss = np.zeros((num_fold,len(times_test)))
prediction = np.zeros((num_fold,len(times_test)))
num_fold=8

for i in range(num_fold):
    # define model path
    print("loading repetition {0} model ...".format(i+1))
    model_path = os.path.join(output_folder,'repetition_'+str(i+1),'best_model_repitition_'+str(i+1)+'.h5')
    # load the trained model
    model = keras.models.load_model(model_path)
    
    # model evaluation
    print("evaluating performance for the model".format(i+1))
    loss[i] = model.evaluate(x=images_log_test, y=pv_log_test, batch_size=200, verbose=1)
    
    # generate prediction
    print("generating predictions for the model".format(i+1))
    prediction[i] = np.squeeze(model.predict(images_log_test, batch_size=200, verbose=1))

# saving predictions from each model
np.save(os.path.join(output_folder,'test_predictions.npy'),prediction)

# using the ensemble mean of the 10 models as the final prediction 
print('-'*50)
print("model ensembling ...")
prediction_ensemble = np.mean(prediction,axis=0)
loss_ensemble = np.sqrt(np.mean((prediction_ensemble-pv_log_test)**2))
print("the test set RMSE is {0:.3f} for the ensemble model".format(loss_ensemble))
# Out:
# loading repetition 1 model ...
# evaluating performance for the model
# 71/71 [==============================] - 1s 5ms/step - loss: 6.2510
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 2 model ...
# evaluating performance for the model
# 71/71 [==============================] - 1s 5ms/step - loss: 5.8949
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 3 model ...
# evaluating performance for the model
# 71/71 [==============================] - 1s 5ms/step - loss: 5.9860
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 4 model ...
# evaluating performance for the model
# 71/71 [==============================] - 1s 5ms/step - loss: 6.5376
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 5 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 5ms/step - loss: 6.8092
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 6 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 5ms/step - loss: 6.0157
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 7 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 5ms/step - loss: 6.4017
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# loading repetition 8 model ...
# evaluating performance for the model
# 71/71 [==============================] - 0s 5ms/step - loss: 5.8513
# generating predictions for the model
# 71/71 [==============================] - 0s 4ms/step
# --------------------------------------------------
# model ensembling ...
# the test set RMSE is 2.347 for the ensemble model

# %%
# formulate sunny and cloudy test days
sunny_dates = [(2017,9,15),(2017,10,6),(2017,10,22),
               (2018,2,16),(2018,6,12),(2018,6,23),
               (2019,1,25),(2019,6,23),(2019,7,14),(2019,10,14)]
cloudy_dates = [(2017,6,24),(2017,9,20),(2017,10,11),
                (2018,1,25),(2018,3,9),(2018,10,4),
                (2019,5,27),(2019,6,28),(2019,8,10),(2019,10,19)]

sunny_dates_test = [datetime.date(day[0],day[1],day[2]) for day in sunny_dates]
cloudy_dates_test = [datetime.date(day[0],day[1],day[2]) for day in cloudy_dates]

dates_test = np.asarray([times.date() for times in times_test])

## generate mask for the sunny days
mask = np.zeros(len(pv_log_test),dtype=bool)
for i in sunny_dates_test:
    mask[np.where(dates_test==i)[0]]=1

## apply the mask to the dataset
times_test_sunny = times_test[mask]
pv_log_test_sunny = pv_log_test[mask]
images_log_test_sunny = images_log_test[mask]
prediction_ensemble_sunny = prediction_ensemble[mask]
print("times_test_sunny.shape:",times_test_sunny.shape)

times_test_cloudy = times_test[~mask]
pv_log_test_cloudy = pv_log_test[~mask]
images_log_test_cloudy = images_log_test[~mask]
prediction_ensemble_cloudy = prediction_ensemble[~mask]
print("times_test_cloudy.shape:",times_test_cloudy.shape)
# Out:
# times_test_sunny.shape: (6986,)
# times_test_cloudy.shape: (7017,)

# %%
# RMSE for sunny and cloudy days individually
rmse_sunny = np.sqrt(np.mean(np.square((prediction_ensemble_sunny-pv_log_test_sunny))))
rmse_cloudy = np.sqrt(np.mean(np.square((prediction_ensemble_cloudy-pv_log_test_cloudy))))
rmse_overall = np.sqrt((rmse_sunny**2*len(pv_log_test_sunny)+rmse_cloudy**2*len(pv_log_test_cloudy))/(len(pv_log_test)))

print("test set sunny days RMSE: {0:.3f}".format(rmse_sunny))
print("test set cloudy days RMSE: {0:.3f}".format(rmse_cloudy))
print("test set overall RMSE: {0:.3f}".format(rmse_overall))
# Out:
# test set sunny days RMSE: 0.675
# test set cloudy days RMSE: 3.246
# test set overall RMSE: 2.347

# %%
# MAE for sunny and cloudy days individually
mae_sunny = np.mean(np.abs((prediction_ensemble_sunny-pv_log_test_sunny)))
mae_cloudy = np.mean(np.abs((prediction_ensemble_cloudy-pv_log_test_cloudy)))
mae_overall = (mae_cloudy*len(pv_log_test_cloudy) + mae_sunny*len(pv_log_test_sunny))/(len(pv_log_test))

print("test set sunny days MAE: {0:.3f}".format(mae_sunny))
print("test set cloudy days MAE: {0:.3f}".format(mae_cloudy))
print("test set overall MAE: {0:.3f}".format(mae_overall))
# Out:
# test set sunny days MAE: 0.547
# test set cloudy days MAE: 2.229
# test set overall MAE: 1.390

# %%
# R² for sunny and cloudy days individually
r2_sunny = 1 - (np.sum(np.square(prediction_ensemble_sunny - pv_log_test_sunny)) / 
                np.sum(np.square(pv_log_test_sunny - np.mean(pv_log_test_sunny))))
r2_cloudy = 1 - (np.sum(np.square(prediction_ensemble_cloudy - pv_log_test_cloudy)) / 
                 np.sum(np.square(pv_log_test_cloudy - np.mean(pv_log_test_cloudy))))
r2_overall = 1 - (np.sum(np.square(np.concatenate([prediction_ensemble_sunny, prediction_ensemble_cloudy]) - 
                                   np.concatenate([pv_log_test_sunny, pv_log_test_cloudy]))) / 
                  np.sum(np.square(np.concatenate([pv_log_test_sunny, pv_log_test_cloudy]) - 
                                   np.mean(np.concatenate([pv_log_test_sunny, pv_log_test_cloudy])))))

print("test set sunny days R²: {0:.3f}".format(r2_sunny))
print("test set cloudy days R²: {0:.3f}".format(r2_cloudy))
print("test set overall R²: {0:.3f}".format(r2_overall))
# Out:
# test set sunny days R²: 0.992
# test set cloudy days R²: 0.814
# test set overall R²: 0.906

# %%
# EVS for sunny and cloudy days individually
evs_sunny = 1 - (np.var(prediction_ensemble_sunny - pv_log_test_sunny) / 
                 np.var(pv_log_test_sunny))
evs_cloudy = 1 - (np.var(prediction_ensemble_cloudy - pv_log_test_cloudy) / 
                  np.var(pv_log_test_cloudy))
evs_overall = 1 - (np.var(np.concatenate([prediction_ensemble_sunny, prediction_ensemble_cloudy]) - 
                          np.concatenate([pv_log_test_sunny, pv_log_test_cloudy])) / 
                   np.var(np.concatenate([pv_log_test_sunny, pv_log_test_cloudy])))

print("test set sunny days EVS: {0:.3f}".format(evs_sunny))
print("test set cloudy days EVS: {0:.3f}".format(evs_cloudy))
print("test set overall EVS: {0:.3f}".format(evs_overall))
# Out:
# test set sunny days EVS: 0.996
# test set cloudy days EVS: 0.823
# test set overall EVS: 0.912

# %%
# visualization of nowcast predictions
dates_test = np.array([dtinfo.date() for dtinfo in times_test])
hours_test = np.array([dtinfo.time() for dtinfo in times_test])

f,axarr = plt.subplots(10,2,sharex=False, sharey = True)
xfmt = mdates.DateFormatter('%H')
fmt_date = datetime.date(2000,1,1)

blue = '#67AFD2'
grey =  '#B6B1A9'

for i,date in enumerate(sunny_dates_test):
    ax = axarr[i,0]
    date_mask = (dates_test == date)
    hours_xaxis= [datetime.datetime.combine(fmt_date, hour) for hour in hours_test[date_mask]] 
    
    rmse = np.sqrt(np.mean(np.square((pv_log_test[date_mask]-prediction_ensemble[date_mask]))))
    mae = np.mean(np.abs((pv_log_test[date_mask]-prediction_ensemble[date_mask])))
    
    ax.plot(hours_xaxis, pv_log_test[date_mask], linewidth = 1,color=grey)
    ax.fill_between(hours_xaxis, 0, pv_log_test[date_mask], color=grey, alpha=.2, label = 'Ground truth')
    ax.plot(hours_xaxis, prediction_ensemble[date_mask],linewidth = 1,label = 'SUNSET nowcast',color=blue,markerfacecolor="None")
    ax.set_ylabel('PV output (kW)')
    ax.xaxis.set_major_formatter(xfmt)
    ax.text(0.75,0.85,'Sunny_'+str(i+1), transform=ax.transAxes)
    ax.text(0.05,0.75,"RMSE: {0:.2f}\nMAE: {1:.2f}".format(rmse,mae),transform=ax.transAxes)

for i,date in enumerate(cloudy_dates_test):
    ax = axarr[i,1]
    date_mask = (dates_test == date)
    hours_xaxis= [datetime.datetime.combine(fmt_date, hour) for hour in hours_test[date_mask]] 
    
    rmse = np.sqrt(np.mean(np.square((pv_log_test[date_mask]-prediction_ensemble[date_mask]))))
    mae = np.mean(np.abs((pv_log_test[date_mask]-prediction_ensemble[date_mask])))
    
    ax.plot(hours_xaxis, pv_log_test[date_mask], linewidth = 1,color=grey)
    ax.fill_between(hours_xaxis, 0, pv_log_test[date_mask], color=grey, alpha=.2, label = 'Ground truth')
    ax.plot(hours_xaxis, prediction_ensemble[date_mask],linewidth = 1,label = 'SUNSET nowcast',color=blue,markerfacecolor="None")
    ax.set_ylabel('PV output (kW)')
    ax.xaxis.set_major_formatter(xfmt)
    ax.text(0.75,0.85,'Cloudy_'+str(i+1), transform=ax.transAxes)
    ax.text(0.05,0.75,"RMSE: {0:.2f}\nMAE: {1:.2f}".format(rmse,mae),transform=ax.transAxes)

    
axarr[0,0].set_ylim(0, 30)
axarr[0,0].legend(bbox_to_anchor= [1.15,1.3], loc = 'upper center', ncol = 3)
axarr[-1,0].set_xlabel('Hour of day')
axarr[-1,1].set_xlabel('Hour of day')

f.set_size_inches(10,25)    
plt.show()
